# %%
pwd
# Out:
# '/home/jovyan/silver-iguana/spark/notebooks'

# %% [markdown]
# <h2 style="color:red; font-weight:bold; text-align:center;">
# How do we prevent an AI model from hallucinating?
# </h2>
#
# Large Language Models (LLMs) can summarize, reason, and synthesize text — but they still **invent facts** and **fail to quantify uncertainty**.
#
# Recent research explores many ways to reduce this problem, yet most solutions remain **qualitative** rather than **mathematical**.
#
# My thesis: *LLMs alone can’t provide trustworthy, numerically grounded predictions without leaning on a statistical framework underneath.*
#
# ---
#
# - **Islam et al. (2024)** — *A Comprehensive Survey of Hallucination Mitigation Techniques in Large Language Models*
#   ([arXiv:2401.01313](https://arxiv.org/abs/2401.01313))
#
#   **Summary:**
#   This paper surveys over 32 attempts to reduce hallucinations — through *prompt engineering*, *retrieval-augmented generation*, *self-refinement*, and *knowledge injection*.
#   The key takeaway: nearly all these methods are **heuristics** — clever but ad hoc fixes — not mathematically grounded systems. None provide true **probabilistic calibration** or **confidence intervals**.
#
#   ![test](Images/Islam.png)
#
#   *Figure:* A taxonomy of mitigation strategies. What’s missing is a **statistical backbone** — none of these approaches measure how confident the model actually is in a mathematically valid way.
#
# ---
#
# - **Liang et al. (2024)** — *THaMES: An End-to-End Tool for Hallucination Mitigation and Evaluation in Large Language Models*
#   ([arXiv:2409.11353](https://arxiv.org/abs/2409.11353))
#
#   ![test](Images/THaMES.png)
#
#   **Summary:**
#   THaMES builds an automated pipeline for mitigating hallucinations by generating QA datasets, benchmarking model responses, and applying methods like **In-Context Learning**, **Retrieval-Augmented Generation**, and **Parameter-Efficient Fine-Tuning**.
#   It does reduce hallucination frequency, but only in a **qualitative** way — classifying outputs as “fact” or “non-fact,” with no mathematical notion of **confidence** or **error bounds**.
#
#   **Why this approach doesn’t fit the Spark / ScoreCard project:**
#   THaMES improves behavior through **data curation and prompt tuning**, not through **statistical validity**.
#   The ScoreCard system, by contrast, must justify **quantitative model outputs** — real probabilities from logistic regression models grounded in procurement data.
#   A THaMES-style pipeline might clean inputs, but it can’t explain *why* a score was produced or *how sure* the system is.
#
#   *In short:* **THaMES reduces hallucination by reshaping data — ScoreCard prevents it by grounding explanations in math.**
#
# ---
#
# - **Pang, Jang & Fang (2024)** — *Generating Descriptive Explanations of Machine Learning Models Using LLM*
#   ([OpenReview PDF](https://openreview.net/pdf/7966b9a46e995f470152dc158cf2c09a957eae89.pdf))
#
#   **Summary:**
#   This paper introduces a complementary strategy: using an LLM as a **translator** between classical machine-learning models and human users.
#   Instead of retraining or altering data, the LLM reads a model’s internal parameters — such as feature weights and correlations — and converts them into **natural-language explanations** describing *how* the model reasons.
#   The insight is simple but powerful: an LLM can offer interpretability **without touching the underlying math**.
#
#   ![test](Images/Pang.png)
#
#   *Figure:* The statistical model remains the **source of truth**, while the LLM acts as the **interpreter** — explaining logic, relevance, and uncertainty to humans.
#   This is the same strategy adopted in the **Spark / ScoreCard** system: use AI not to alter the numbers, but to **explain and justify** them in plain language.

# %%
import sys
import os

# Just for demo purposes
sys.path.insert(0, os.path.abspath(os.path.join("..", "src")))

from scorecard import (ScoreCardConfig, 
                      ScoreCardState, 
                      ConnectionManager,
                      ScoreCardModeling,
                      ScoreCardRag,
                      ScoreCardPipeline,
                      Horizon,              # Multi-horizon support
                      SUPPORTED_HORIZONS)   # List of supported horizons


config = ScoreCardConfig()
state = ScoreCardState(config)
conn = ConnectionManager(config, state)
modeler = ScoreCardModeling(config, state, conn)
rag = ScoreCardRag(config, state, conn)

pipeline = ScoreCardPipeline(config, state, conn, modeler)

# %% [markdown]
# This notebook demonstrates a **hybrid model pipeline** for vendor performance classification and explanation — integrating **statistical modeling**, **vector search**, and **generative reasoning**. The architecture connects classical machine learning, dense embedding retrieval, and GPT-based justification into one coherent system.
#
# ---
#
# ## Hybrid Modeling Approach
#
# The system has three main layers:
#
# ---
#
# ### 1. **Logistic Regression over Linguistic Features**
#
# Implemented in the `ScoreCardModeling` class — this is the **statistical core** of the ScoreCard system.
#
# ---
#
# #### What is Logistic Regression?
#
# Logistic regression is a **classification algorithm** that predicts the probability of an outcome (e.g., Green, Yellow, or Red).
# It combines input features linearly and passes that score through a **sigmoid** (or softmax) function to produce probabilities between 0 and 1.
#
# $
# P(y \in \{\text{Green, Yellow, Red}\} \mid \vec{x}) = \text{softmax}(W\vec{x} + b)
# $
#
# Where:
# - $\vec{x}$ = vectorized representation of each supplier note and its metadata
# - $W$ = learned feature weights (interpretable coefficients)
# - $b$ = bias term
#
# Because logistic regression is **transparent**, we can inspect which words and features drive predictions — and even attach **confidence intervals** to them.
#
# ---
#
# #### Vectorization: Turning Text into Numbers
#
# LLMs and machine learning models can only “understand” text once it’s represented as **vectors** — numerical encodings of meaning.
# In this pipeline, we **vectorize nouns, verbs, and adjectives** from supplier notes to capture both *what happened* (nouns) and *how it was described* (verbs/adjectives).
#
# Example:
#
# > “Vendor missed the critical delivery deadline.”
#
# becomes feature tokens like:
# - **Nouns:** `vendor`, `delivery`, `deadline`
# - **Verbs/Adjectives:** `missed`, `critical`
#
# These are then transformed into numeric vectors using **Count**, **TF-IDF**, or **Embedding** encoders.
#
# ---
#
# #### Word Embedding Analogy
#
# Vectorization allows words to occupy positions in a multidimensional space, preserving relationships between meanings.
# A famous example is:
#
# $
# \text{king} - \text{man} + \text{woman} \approx \text{queen}
# $
#
# In the ScoreCard context, this concept generalizes to vendor language:
#
# > “missed deadline” − “late” + “resolved” → closer to “on time”
#
# It’s how the model captures semantic nuance beyond raw text.
#
# ![Word embedding analogy: king - man + woman = queen](https://kawine.github.io/blog/assets/parallelogram.png)
#
# ---
#
# #### Building and Tuning the Model
#
# The `build_model_grid` method performs a **structured grid search** across:
#
# - Feature sets (linguistic vs. metadata)
# - Sampling strategies (e.g., downsample overrepresented Green cases)
# - Vectorizer types (`count`, `tfidf`, etc.)
# - Class weights (penalize risky misclassifications more heavily)
#
# This process — known as **hyperparameter tuning** — systematically trains dozens of logistic models to find the best balance between **interpretability** and **predictive strength**.
#
# ![Logistic regression S-curve](Images/logreg.jpg)
#
# ---
#
# #### Evaluation and Selection
#
# Each candidate model is trained and tested (80/20 split) and scored on:
# - **False negatives** — our top priority (don’t classify risky vendors as “green”)
# - **Overall accuracy**
# - **Confusion matrix structure**
#
# Selection rule:
# 1. Minimize false negatives
# 2. Use test accuracy as a tie-breaker
#
# This ensures a **safety-sensitive bias** toward over-detection rather than under-detection.
#
# ---
#
# #### Why This Matters
#
# Unlike opaque neural models, logistic regression provides:
# - **Transparent coefficients** showing which terms push a note toward Red, Yellow, or Green
# - **Probabilistic outputs** with mathematically valid confidence levels
# - **Explainable logic** where every prediction can be traced to specific linguistic or metadata features
#
# Together, this forms the **quantitative foundation** of the ScoreCard system:
# > The model predicts with math — the LLM later explains with language.
#
#
# ### 2. **Vector Store of Notes (RAG)**
#
# Past scorecard notes are embedded and indexed in a local Elasticsearch dense vector store (`scorecard_rag_notes`).
#
# ![RAG](Images/RAG.png)
#
#
# - Each note → 1024-dimensional vector via `SentenceTransformer` (“BAAI/bge-large-en-v1.5”)
# - Metadata (date, SID, label) stored for contextual retrieval
#
# Managed by the `ScoreCardRag` class:
# - `embed_and_index_notes`: builds embeddings and indexes
# - `similar_notes_same_sid`: finds earlier notes for the same supplier
# - `get_vendor_trouble_notes`: retrieves non-green notes across contracts
#
# This allows **semantic retrieval** — finding related issues without keyword overlap.
#
# ---
#
# ### 3. **GPT-Based Justification Engine**
#
# After prediction, GPT-4o generates a natural-language **justification** of the label.
#
# Prompts include:
# - The vendor’s note history (`sid_key_0–3`)
# - Similar notes retrieved via RAG
# - Vendor-level context (other non-green scores)
#
# Executed through:
# - `ScoreCardRag.generate_justifications`: prompt construction and GPT call
# - `run_gpt_justification_pass`: parallelized execution with backoff/retry logic
#
# Example output:
#
# > “This vendor is trending yellow due to repeated late-delivery notes and unresponsiveness, consistent with similar issues in SID 301884.”
#
# Thus, the LLM supplies **qualitative reasoning** that complements the model’s **quantitative prediction**.
#
# ---
#
# ### Pipeline Integration
#
# The `ScoreCardPipeline` class orchestrates end-to-end flow:
# 1. `_stage_1_download` — load data from SQL / Elasticsearch
# 2. `_stage_2_text_enrichment` — NLP preprocessing and note windowing
# 3. `_stage_3_modeling_and_prediction` — train or load the best logistic model, generate predictions
# 4. Optionally trigger GPT justifications
#
# Overall:
#
# $$
# \text{Prediction} = \text{LogisticRegression}(\text{Linguistic Features})
# $$
#
# $$
# \text{Explanation} = \text{GPT-4o}(\text{Note History + Vector Similarity})
# $$
#
# This hybrid pipeline delivers **statistical precision**, **semantic memory**, and **contextual explanations** — bridging classical analytics with modern generative AI.

# %%
pipeline.run()
# Out:
# [SQL] 	28118 rows downloaded and stored in state.details_df.
# [ES] 	Indexed 28118 documents to 'scorecard_details' with 0 errors.
# [PIPE] 	Completed all Downloads from SQL or ES
# /home/jovyan/.local/lib/python3.11/site-packages/thinc/util.py:395: VisibleDeprecationWarning: This function is deprecated and will be removed in a future release. Use the cupy.from_dlpack() array constructor instead.
#   dlpack_tensor = xp_tensor.toDlpack()  # type: ignore
# [ES] 	Indexed 28087 documents to 'scorecard_enriched' with 0 errors.
# [ES] 	Indexed 28087 documents to 'scorecard_sid_history' with 0 errors.
# [PIPE] 	Completed all Text Prep Steps
# [DATA] 	Filtered to 23982 trainable rows with total_notes >= 5 and valid target (0/1/2) 14.6% culled
# [MODL] 	Rehydrated best model: complete_main_words_only | no_downsample_weighted | count | Weights {0: 0.5, 1: 1.35, 2: 1.15}
# [ML] 	Best model: complete_main_words_only | no_downsample_weighted | count | Weights {0: 0.5, 1: 1.35, 2: 1.15}
# [ES] 	Indexed 0 documents to 'scorecard_model_summary' with 0 errors.
# [ES] 	Indexed 28087 documents to 'scorecard_predictions' with 0 errors.
# [ML] 	Predictions uploaded to 'scorecard_predictions'
# [JOIN] 	Merged predictions into enriched_df. Final shape: (28087, 56)

# %% [markdown]
# ## Multi-Horizon Prediction Results
#
# The pipeline now supports **two prediction horizons**:
#
# | Horizon | Description | Target | Minimum Notes |
# |---------|-------------|--------|---------------|
# | **H1** | Next card prediction | 1 step ahead | 5 notes |
# | **H2** | Card after next | 2 steps ahead | 6 notes |
#
# ### Key Design Decisions
#
# 1. **No Recursive Predictions**: H2 is trained directly from historical data, NOT conditioned on H1 predictions
# 2. **Backward Compatibility**: H1 uses original column names (`trainable`, `target`, `predicted_label`); H2 uses `_h2` suffix
# 3. **Separate Models**: Each horizon has its own trained model with independent evaluation metrics
#
# ### Output Columns
#
# After running `pipeline.run()`, `state.complete_df` contains:
#
# **H1 Columns (original names):**
# - `predicted_label` - H1 predicted label (0=Green, 1=Yellow, 2=Red)
# - `prob_green`, `prob_yellow`, `prob_red` - H1 probabilities
# - `predicted_color` - Human-readable H1 prediction
#
# **H2 Columns (with _h2 suffix):**
# - `predicted_label_h2` - H2 predicted label
# - `prob_green_h2`, `prob_yellow_h2`, `prob_red_h2` - H2 probabilities
# - `predicted_color_h2` - Human-readable H2 prediction

# %%
import pandas as pd
from IPython.display import display, Markdown

def display_one_note(row: pd.Series) -> None:
    """
    Nicely displays a single ScoreCard prediction with H1 and H2 results.
    Updated for multi-horizon prediction support.
    
    Example use:
        display_one_note(pipeline.state.complete_df.sample(1).iloc[0])
    """

    sid = row.get("SID", "unknown")
    note = row.get("Scorecard_Note", "").strip()
    supplier = row.get("Supplier_Name", "").strip()
    program = row.get("Program_Name", "")
    year = row.get("Note_Year", "")
    
    # H1 prediction (original column names)
    color_h1 = row.get("predicted_color", "Unknown").title()
    p_green_h1 = row.get("prob_green", 0)
    p_yellow_h1 = row.get("prob_yellow", 0)
    p_red_h1 = row.get("prob_red", 0)
    
    # H2 prediction (with _h2 suffix)
    color_h2 = row.get("predicted_color_h2", "N/A")
    if pd.notna(color_h2) and color_h2 != "N/A":
        color_h2 = str(color_h2).title()
    else:
        color_h2 = "N/A"
    p_green_h2 = row.get("prob_green_h2", None)
    p_yellow_h2 = row.get("prob_yellow_h2", None)
    p_red_h2 = row.get("prob_red_h2", None)

    # Choose style by H1 color
    if color_h1 == "Red":
        style = '<hr style="border-top: 3px double #d33;">'
    elif color_h1 == "Yellow":
        style = '<hr style="border-top: 3px double #e6c300;">'
    else:
        style = '<hr style="border-top: 3px double #3a9c35;">'

    # Format H2 probabilities (may be missing if not enough notes)
    if p_green_h2 is not None and pd.notna(p_green_h2):
        h2_probs = f"""- Green: {p_green_h2:.5f}  
- Yellow: {p_yellow_h2:.5f}  
- Red: {p_red_h2:.5f}"""
    else:
        h2_probs = "*(Insufficient note history for H2 prediction)*"

    # Markdown block with both horizons
    md = f"""
{style}

**SID:** `{sid}`  **Program:** *{program}* **Supplier:** *{supplier}*  **Year:** {year}  

---

**Scorecard Note:**  
> {note}

---

### H1: Next Card Prediction
**Predicted Rating: {color_h1}**

**Model Probabilities**  
- Green: {p_green_h1:.5f}  
- Yellow: {p_yellow_h1:.5f}  
- Red: {p_red_h1:.5f}  

---

### H2: Card After Next Prediction
**Predicted Rating: {color_h2}**

**Model Probabilities**  
{h2_probs}

{style}
"""
    display(Markdown(md))

# %%
# Sample a note and display both H1 and H2 predictions
sample = pipeline.state.complete_df[[
    "SID", 
    "Scorecard_Note",
    "Supplier_Name",
    "Note_Year",
    "Program_Name",
    "color_set",
    # H1 columns (original names)
    "prob_green",
    "prob_yellow",
    "prob_red",
    "predicted_color",
    # H2 columns (with _h2 suffix)
    "prob_green_h2",
    "prob_yellow_h2",
    "prob_red_h2",
    "predicted_color_h2"
]].sample()

display_one_note(sample.iloc[0])

# %% [markdown]
# ### Horizon Comparison Analysis
#
# Let's examine how H1 and H2 predictions differ across the dataset.

# %%
# Horizon comparison analysis
df_complete = pipeline.state.complete_df

# Count predictions by horizon
h1_counts = df_complete['predicted_color'].value_counts()
h2_counts = df_complete['predicted_color_h2'].dropna().value_counts()

print("=" * 50)
print("H1 (Next Card) Prediction Distribution:")
print("=" * 50)
for color, count in h1_counts.items():
    print(f"  {color}: {count:,} ({100*count/len(df_complete):.1f}%)")

print("\n" + "=" * 50)
print("H2 (Card After Next) Prediction Distribution:")
print("=" * 50)
h2_total = df_complete['predicted_color_h2'].notna().sum()
for color, count in h2_counts.items():
    print(f"  {color}: {count:,} ({100*count/h2_total:.1f}%)")
print(f"\n  (H2 predictions available for {h2_total:,} of {len(df_complete):,} rows)")

# Show cases where H1 and H2 predictions differ
both_available = df_complete.dropna(subset=['predicted_color', 'predicted_color_h2'])
differs = both_available[both_available['predicted_color'] != both_available['predicted_color_h2']]
print(f"\n" + "=" * 50)
print(f"Horizon Disagreement:")
print("=" * 50)
print(f"  {len(differs):,} rows ({100*len(differs)/len(both_available):.1f}%) have different H1 vs H2 predictions")

# %%
# Access per-horizon model information
print("=" * 60)
print("Best Model Keys by Horizon:")
print("=" * 60)

for horizon in SUPPORTED_HORIZONS:
    key = state.best_model_key_by_horizon.get(int(horizon), "Not trained")
    print(f"\n  Horizon {horizon} (H{int(horizon)}):")
    print(f"    {key}")

# Show per-horizon predictions DataFrames
print("\n" + "=" * 60)
print("Per-Horizon Predictions DataFrames:")
print("=" * 60)
for horizon in SUPPORTED_HORIZONS:
    df_h = state.predictions_df_by_horizon.get(int(horizon))
    if df_h is not None:
        print(f"\n  H{int(horizon)}: {len(df_h):,} rows, {len(df_h.columns)} columns")
    else:
        print(f"\n  H{int(horizon)}: Not available")

# %% [markdown]
# ## Model Validation: Confusion Matrices & Metrics
#
# This section evaluates the predictive performance of both H1 (next card) and H2 (card after next) models using:
#
# - **Confusion Matrix**: Shows true vs predicted labels for each class (Green/Yellow/Red)
# - **Classification Metrics**: Precision, Recall, F1-Score per class
# - **Overall Accuracy**: Percentage of correct predictions
# - **False Negative Analysis**: Critical for safety - identifying risky vendors misclassified as Green
#
# Note: Validation is performed only on **trainable** rows where ground truth targets are available.

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns

def plot_confusion_matrix(y_true, y_pred, title, labels=['Green', 'Yellow', 'Red']):
    """
    Plot a confusion matrix with counts and percentages.
    """
    cm = confusion_matrix(y_true, y_pred, labels=[0, 1, 2])
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    
    # Raw counts
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=labels, yticklabels=labels, ax=axes[0])
    axes[0].set_xlabel('Predicted')
    axes[0].set_ylabel('Actual')
    axes[0].set_title(f'{title} - Counts')
    
    # Normalized (percentages)
    sns.heatmap(cm_normalized, annot=True, fmt='.1%', cmap='Blues',
                xticklabels=labels, yticklabels=labels, ax=axes[1])
    axes[1].set_xlabel('Predicted')
    axes[1].set_ylabel('Actual')
    axes[1].set_title(f'{title} - Normalized by Row')
    
    plt.tight_layout()
    plt.show()
    
    return cm

def compute_false_negatives(y_true, y_pred):
    """
    Compute false negatives: Yellow/Red predicted as Green (safety-critical).
    """
    fn_yellow = sum((y_true == 1) & (y_pred == 0))  # Yellow predicted as Green
    fn_red = sum((y_true == 2) & (y_pred == 0))     # Red predicted as Green
    total_yellow = sum(y_true == 1)
    total_red = sum(y_true == 2)
    
    return {
        'yellow_as_green': fn_yellow,
        'yellow_total': total_yellow,
        'yellow_fn_rate': fn_yellow / total_yellow if total_yellow > 0 else 0,
        'red_as_green': fn_red,
        'red_total': total_red,
        'red_fn_rate': fn_red / total_red if total_red > 0 else 0,
        'total_fn': fn_yellow + fn_red
    }

def print_validation_report(y_true, y_pred, horizon_name):
    """
    Print comprehensive validation metrics.
    """
    print("=" * 70)
    print(f"  {horizon_name} VALIDATION REPORT")
    print("=" * 70)
    
    # Overall accuracy
    acc = accuracy_score(y_true, y_pred)
    print(f"\nOverall Accuracy: {acc:.4f} ({100*acc:.2f}%)")
    print(f"Total Samples: {len(y_true):,}")
    
    # Classification report
    print("\n" + "-" * 70)
    print("Classification Report:")
    print("-" * 70)
    print(classification_report(y_true, y_pred, 
                                target_names=['Green (0)', 'Yellow (1)', 'Red (2)'],
                                digits=4))
    
    # False negative analysis (safety-critical)
    fn_stats = compute_false_negatives(y_true, y_pred)
    print("-" * 70)
    print("False Negative Analysis (Safety-Critical):")
    print("-" * 70)
    print(f"  Yellow misclassified as Green: {fn_stats['yellow_as_green']:,} / {fn_stats['yellow_total']:,} ({100*fn_stats['yellow_fn_rate']:.2f}%)")
    print(f"  Red misclassified as Green:    {fn_stats['red_as_green']:,} / {fn_stats['red_total']:,} ({100*fn_stats['red_fn_rate']:.2f}%)")
    print(f"  Total False Negatives:         {fn_stats['total_fn']:,}")
    print("=" * 70 + "\n")
    
    return fn_stats

# %% [markdown]
# ### H1: Next Card Prediction Validation
#
# Evaluating the model that predicts the **next** scorecard rating (1 step ahead).

# %%
# H1 Validation: Filter to trainable rows with valid targets
df_complete = pipeline.state.complete_df.copy()

# H1 uses original column names: 'trainable' and 'target'
h1_valid = df_complete[
    (df_complete['trainable'] == True) & 
    (df_complete['target'].isin([0, 1, 2])) &
    (df_complete['predicted_label'].notna())
].copy()

y_true_h1 = h1_valid['target'].astype(int).values
y_pred_h1 = h1_valid['predicted_label'].astype(int).values

print(f"H1 Validation Set: {len(h1_valid):,} trainable rows with valid targets\n")

# Print validation report
h1_fn_stats = print_validation_report(y_true_h1, y_pred_h1, "H1 (Next Card)")

# Plot confusion matrix
cm_h1 = plot_confusion_matrix(y_true_h1, y_pred_h1, "H1: Next Card Prediction")

# %% [markdown]
# ### H2: Card After Next Prediction Validation
#
# Evaluating the model that predicts the scorecard rating **two steps ahead**.
#
# Note: H2 requires more historical notes (6+), so the validation set is smaller than H1.

# %%
# H2 Validation: Filter to trainable_h2 rows with valid targets
# H2 uses _h2 suffix: 'trainable_h2' and 'target_h2'

# Check if H2 columns exist
if 'trainable_h2' in df_complete.columns and 'target_h2' in df_complete.columns:
    h2_valid = df_complete[
        (df_complete['trainable_h2'] == True) & 
        (df_complete['target_h2'].isin([0, 1, 2])) &
        (df_complete['predicted_label_h2'].notna())
    ].copy()
    
    if len(h2_valid) > 0:
        y_true_h2 = h2_valid['target_h2'].astype(int).values
        y_pred_h2 = h2_valid['predicted_label_h2'].astype(int).values
        
        print(f"H2 Validation Set: {len(h2_valid):,} trainable rows with valid targets\n")
        
        # Print validation report
        h2_fn_stats = print_validation_report(y_true_h2, y_pred_h2, "H2 (Card After Next)")
        
        # Plot confusion matrix
        cm_h2 = plot_confusion_matrix(y_true_h2, y_pred_h2, "H2: Card After Next Prediction")
    else:
        print("No valid H2 validation data available.")
        print("Ensure the pipeline was run with H2 model training enabled.")
else:
    print("H2 columns not found in complete_df.")
    print("Ensure the pipeline was run with multi-horizon support enabled.")

# %% [markdown]
# ### Horizon Comparison Summary
#
# Side-by-side comparison of H1 and H2 model performance.

# %%
# Side-by-side comparison of H1 and H2 performance
from sklearn.metrics import precision_recall_fscore_support

def get_metrics_summary(y_true, y_pred):
    """Extract key metrics for comparison."""
    acc = accuracy_score(y_true, y_pred)
    precision, recall, f1, support = precision_recall_fscore_support(
        y_true, y_pred, labels=[0, 1, 2], average=None, zero_division=0
    )
    fn_stats = compute_false_negatives(y_true, y_pred)
    
    return {
        'accuracy': acc,
        'precision_green': precision[0],
        'precision_yellow': precision[1],
        'precision_red': precision[2],
        'recall_green': recall[0],
        'recall_yellow': recall[1],
        'recall_red': recall[2],
        'f1_green': f1[0],
        'f1_yellow': f1[1],
        'f1_red': f1[2],
        'fn_yellow_rate': fn_stats['yellow_fn_rate'],
        'fn_red_rate': fn_stats['red_fn_rate'],
        'total_fn': fn_stats['total_fn'],
        'samples': len(y_true)
    }

# Build comparison table
h1_metrics = get_metrics_summary(y_true_h1, y_pred_h1)

comparison_data = {
    'Metric': [
        'Validation Samples',
        'Overall Accuracy',
        '',
        'Precision - Green',
        'Precision - Yellow', 
        'Precision - Red',
        '',
        'Recall - Green',
        'Recall - Yellow',
        'Recall - Red',
        '',
        'F1-Score - Green',
        'F1-Score - Yellow',
        'F1-Score - Red',
        '',
        'False Neg Rate (Yellow→Green)',
        'False Neg Rate (Red→Green)',
        'Total False Negatives'
    ],
    'H1 (Next Card)': [
        f"{h1_metrics['samples']:,}",
        f"{h1_metrics['accuracy']:.4f}",
        '',
        f"{h1_metrics['precision_green']:.4f}",
        f"{h1_metrics['precision_yellow']:.4f}",
        f"{h1_metrics['precision_red']:.4f}",
        '',
        f"{h1_metrics['recall_green']:.4f}",
        f"{h1_metrics['recall_yellow']:.4f}",
        f"{h1_metrics['recall_red']:.4f}",
        '',
        f"{h1_metrics['f1_green']:.4f}",
        f"{h1_metrics['f1_yellow']:.4f}",
        f"{h1_metrics['f1_red']:.4f}",
        '',
        f"{h1_metrics['fn_yellow_rate']:.2%}",
        f"{h1_metrics['fn_red_rate']:.2%}",
        f"{h1_metrics['total_fn']:,}"
    ]
}

# Add H2 metrics if available
if 'y_true_h2' in dir() and len(y_true_h2) > 0:
    h2_metrics = get_metrics_summary(y_true_h2, y_pred_h2)
    comparison_data['H2 (Card After Next)'] = [
        f"{h2_metrics['samples']:,}",
        f"{h2_metrics['accuracy']:.4f}",
        '',
        f"{h2_metrics['precision_green']:.4f}",
        f"{h2_metrics['precision_yellow']:.4f}",
        f"{h2_metrics['precision_red']:.4f}",
        '',
        f"{h2_metrics['recall_green']:.4f}",
        f"{h2_metrics['recall_yellow']:.4f}",
        f"{h2_metrics['recall_red']:.4f}",
        '',
        f"{h2_metrics['f1_green']:.4f}",
        f"{h2_metrics['f1_yellow']:.4f}",
        f"{h2_metrics['f1_red']:.4f}",
        '',
        f"{h2_metrics['fn_yellow_rate']:.2%}",
        f"{h2_metrics['fn_red_rate']:.2%}",
        f"{h2_metrics['total_fn']:,}"
    ]

comparison_df = pd.DataFrame(comparison_data)
print("=" * 70)
print("  HORIZON COMPARISON SUMMARY")
print("=" * 70)
display(comparison_df.set_index('Metric'))

# %%
# Visual comparison of H1 vs H2 key metrics
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

metrics_to_plot = ['accuracy', 'recall_yellow', 'recall_red']
metric_labels = ['Overall Accuracy', 'Yellow Recall', 'Red Recall']
colors = ['#2ecc71', '#f1c40f', '#e74c3c']

for idx, (metric, label, color) in enumerate(zip(metrics_to_plot, metric_labels, colors)):
    values = [h1_metrics[metric]]
    labels = ['H1']
    
    if 'h2_metrics' in dir():
        values.append(h2_metrics[metric])
        labels.append('H2')
    
    bars = axes[idx].bar(labels, values, color=color, alpha=0.7, edgecolor='black')
    axes[idx].set_title(label, fontsize=12, fontweight='bold')
    axes[idx].set_ylim(0, 1.0)
    axes[idx].set_ylabel('Score')
    
    # Add value labels on bars
    for bar, val in zip(bars, values):
        axes[idx].text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.02,
                      f'{val:.3f}', ha='center', va='bottom', fontsize=11)

plt.suptitle('H1 vs H2 Model Performance Comparison', fontsize=14, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

# False negative comparison
fig, ax = plt.subplots(figsize=(10, 5))

fn_metrics = ['fn_yellow_rate', 'fn_red_rate']
fn_labels = ['Yellow → Green\n(False Negative)', 'Red → Green\n(False Negative)']
x = np.arange(len(fn_labels))
width = 0.35

h1_fn_values = [h1_metrics[m] for m in fn_metrics]
bars1 = ax.bar(x - width/2, h1_fn_values, width, label='H1 (Next Card)', color='#3498db', alpha=0.8)

if 'h2_metrics' in dir():
    h2_fn_values = [h2_metrics[m] for m in fn_metrics]
    bars2 = ax.bar(x + width/2, h2_fn_values, width, label='H2 (Card After Next)', color='#9b59b6', alpha=0.8)

ax.set_ylabel('False Negative Rate')
ax.set_title('False Negative Rates by Horizon (Lower is Better)', fontsize=12, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(fn_labels)
ax.legend()
ax.set_ylim(0, max(h1_fn_values + (h2_fn_values if 'h2_metrics' in dir() else [])) * 1.3 + 0.05)

# Add value labels
for bar in bars1:
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01,
           f'{bar.get_height():.1%}', ha='center', va='bottom', fontsize=10)
if 'h2_metrics' in dir():
    for bar in bars2:
        ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01,
               f'{bar.get_height():.1%}', ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.show()

# %%
rag.embed_and_index_notes()
# Out:
# [EMBD] 	Encoding 28087 notes for embedding...
# Batches:   0%|          | 0/220 [00:00<?, ?it/s]
# [EMBD] 	Token count stats: {
#   "count": 28087.0,
#   "mean": 187.10382027272402,
#   "std": 314.3341133517609,
#   "min": 0.0,
#   "25%": 32.0,
#   "50%": 93.0,
#   "75%": 241.0,
#   "max": 13213.0
# }
# [ES] 	Deleted existing index 'scorecard_rag_notes'
# [ES] 	Created index 'scorecard_rag_notes' with vector mapping
# [ES] 	Indexed 28087 documents to 'scorecard_rag_notes'

# %%
rag.run_gpt_justification_pass()
# Out:
# [RAG] 	No prior notes found for SID 4 before 2018-1
# [RAG] 	No prior notes found for SID 4 before 2018-1
# [RAG] 	No prior notes found for SID 4 before 2018-1
# [RAG] 	No prior notes found for SID 4 before 2018-1
# [RAG] 	No prior notes found for SID 4 before 2018-1
# [RAG] 	No prior notes found for SID 3 before 2018-8
# [RAG] 	No prior notes found for SID 3 before 2018-8
# [RAG] 	No prior notes found for SID 4 before 2018-1
# [RAG] 	No prior notes found for SID 3 before 2018-8
# [RAG] 	No prior notes found for SID 1 before 2017-12
# [RAG] 	No prior notes found for SID 4 before 2018-1
# [RAG] 	No prior notes found for SID 3 before 2018-8
# [RAG] 	No prior notes found for SID 4 before 2018-1
# [RAG] 	No prior notes found for SID 2 before 2016-2
# [GPT] 	[15] 000002.2016.03.000008 succeeded (attempt 1)
# [GPT] 	[30] 000004.2018.01.000023 succeeded (attempt 1)
# [GPT] 	[24] 000004.2018.01.000015 succeeded (attempt 1)
# [GPT] 	[27] 000004.2018.01.000018 succeeded (attempt 1)
# [GPT] 	[22] 000003.2020.03.004593 succeeded (attempt 1)
# [GPT] 	[4] 000001.2018.02.000004 succeeded (attempt 1)
# [GPT] 	[50] 000004.2023.01.028072 succeeded (attempt 1)
# [GPT] 	[37] 000004.2021.05.003358 succeeded (attempt 1)
# [GPT] 	[10] 000001.2019.01.002230 succeeded (attempt 1)
# [GPT] 	[18] 000003.2018.08.000012 succeeded (attempt 1)
# [GPT] 	[14] 000002.2016.02.000007 succeeded (attempt 1)
# [GPT] 	[17] 000003.2018.08.000011 succeeded (attempt 1)
# [GPT] 	[46] 000004.2022.09.025431 succeeded (attempt 1)
# [GPT] 	[29] 000004.2018.01.000022 succeeded (attempt 1)
# [GPT] 	[43] 000004.2022.05.023646 succeeded (attempt 1)
# [GPT] 	[21] 000003.2019.08.004592 succeeded (attempt 1)
# [GPT] 	[51] 000004.2023.02.028546 succeeded (attempt 1)
# [GPT] 	[16] 000003.2018.08.000010 succeeded (attempt 1)
# [GPT] 	[8] 000001.2019.01.001001 succeeded (attempt 1)
# [GPT] 	[42] 000004.2022.04.022205 succeeded (attempt 1)
# [GPT] 	[44] 000004.2022.06.024139 succeeded (attempt 1)
# [GPT] 	[28] 000004.2018.01.000021 succeeded (attempt 1)
# [GPT] 	[52] 000004.2023.03.028914 succeeded (attempt 1)
# [GPT] 	[25] 000004.2018.01.000016 succeeded (attempt 1)
# [GPT] 	[57] 000004.2023.08.031074 succeeded (attempt 1)
# [GPT] 	[38] 000004.2021.06.017513 succeeded (attempt 1)
# [GPT] 	[48] 000004.2022.11.027302 succeeded (attempt 1)
# [GPT] 	[31] 000004.2018.08.000019 succeeded (attempt 1)
# [GPT] 	[33] 000004.2018.08.001025 succeeded (attempt 1)
# [GPT] 	[34] 000004.2018.08.001026 succeeded (attempt 1)
# [GPT] 	[47] 000004.2022.10.025964 succeeded (attempt 1)
# [GPT] 	[26] 000004.2018.01.000017 succeeded (attempt 1)
# [GPT] 	[61] 000004.2023.12.033857 succeeded (attempt 1)
# [GPT] 	[19] 000003.2018.08.000013 succeeded (attempt 1)
# [GPT] 	[35] 000004.2018.08.001027 succeeded (attempt 1)
# [GPT] 	[0] 000001.2017.12.000927 succeeded (attempt 1)
# [GPT] 	[60] 000004.2023.11.033472 succeeded (attempt 1)
# [GPT] 	[36] 000004.2018.08.001028 succeeded (attempt 1)
# [GPT] 	[2] 000001.2018.02.000002 succeeded (attempt 1)
# [GPT] 	[23] 000004.2018.01.000014 succeeded (attempt 1)
# [GPT] 	[5] 000001.2018.02.000005 succeeded (attempt 1)
# [GPT] 	[45] 000004.2022.07.024547 succeeded (attempt 1)
# [GPT] 	[11] 000001.2019.05.005672 succeeded (attempt 1)
# [GPT] 	[12] 000001.2019.05.005774 succeeded (attempt 1)
# [GPT] 	[62] 000004.2024.01.034137 succeeded (attempt 1)
# [GPT] 	[58] 000004.2023.09.032600 succeeded (attempt 1)
# [GPT] 	[54] 000004.2023.05.029933 succeeded (attempt 1)
# [GPT] 	[3] 000001.2018.02.000003 succeeded (attempt 1)
# [GPT] 	[6] 000001.2018.02.000006 succeeded (attempt 1)
# [GPT] 	[7] 000001.2018.06.002229 succeeded (attempt 1)
# [GPT] 	[40] 000004.2022.02.021375 succeeded (attempt 1)
# [GPT] 	[9] 000001.2019.01.002228 succeeded (attempt 1)
# [GPT] 	[59] 000004.2023.10.033086 succeeded (attempt 1)
# [GPT] 	[13] 000001.2019.06.003524 succeeded (attempt 1)
# [GPT] 	[53] 000004.2023.04.029453 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 5 before 2019-7
# [RAG] 	No prior notes found for SID 5 before 2019-7
# [GPT] 	[20] 000003.2018.10.000009 succeeded (attempt 1)
# [GPT] 	[55] 000004.2023.06.030278 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 5 before 2019-7
# [GPT] 	[39] 000004.2022.01.018076 succeeded (attempt 1)
# [GPT] 	[49] 000004.2022.12.027745 succeeded (attempt 1)
# [GPT] 	[63] 000004.2024.02.034549 succeeded (attempt 1)
# [GPT] 	[56] 000004.2023.07.030729 succeeded (attempt 1)
# [GPT] 	[1] 000001.2018.02.000001 succeeded (attempt 1)
# [GPT] 	[41] 000004.2022.03.021701 succeeded (attempt 1)
# [GPT] 	[32] 000004.2018.08.000020 succeeded (attempt 1)
# [GPT] 	[64] 000004.2024.03.034973 succeeded (attempt 1)
# [GPT] 	[65] 000004.2024.04.035476 succeeded (attempt 1)
# [GPT] 	[83] 000004.2025.09.039526 succeeded (attempt 1)
# [GPT] 	[89] 000005.2019.07.000026 succeeded (attempt 1)
# [GPT] 	[75] 000004.2025.02.039699 succeeded (attempt 1)
# [GPT] 	[86] 000004.2025.09.042505 succeeded (attempt 1)
# [GPT] 	[79] 000004.2025.06.039531 succeeded (attempt 1)
# [GPT] 	[74] 000004.2025.01.039252 succeeded (attempt 1)
# [GPT] 	[82] 000004.2025.07.041821 succeeded (attempt 1)
# [GPT] 	[66] 000004.2024.05.035974 succeeded (attempt 1)
# [GPT] 	[88] 000005.2019.07.000024 succeeded (attempt 1)
# [GPT] 	[81] 000004.2025.06.041354 succeeded (attempt 1)
# [GPT] 	[71] 000004.2024.10.038192 succeeded (attempt 1)
# [GPT] 	[80] 000004.2025.06.039702 succeeded (attempt 1)
# [GPT] 	[97] 000005.2020.05.011499 succeeded (attempt 1)
# [GPT] 	[102] 000005.2021.08.016528 succeeded (attempt 1)
# [GPT] 	[93] 000005.2019.10.000028 succeeded (attempt 1)
# [GPT] 	[95] 000005.2020.05.000029 succeeded (attempt 1)
# [GPT] 	[104] 000005.2021.12.020572 succeeded (attempt 1)
# [GPT] 	[121] 000005.2023.04.029469 succeeded (attempt 1)
# [GPT] 	[68] 000004.2024.07.036929 succeeded (attempt 1)
# [GPT] 	[94] 000005.2020.05.000025 succeeded (attempt 1)
# [GPT] 	[84] 000004.2025.09.039530 succeeded (attempt 1)
# [GPT] 	[72] 000004.2024.11.038686 succeeded (attempt 1)
# [GPT] 	[90] 000005.2019.07.000027 succeeded (attempt 1)
# [GPT] 	[67] 000004.2024.06.036462 succeeded (attempt 1)
# [GPT] 	[73] 000004.2024.12.039014 succeeded (attempt 1)
# [GPT] 	[109] 000005.2022.04.022282 succeeded (attempt 1)
# [GPT] 	[120] 000005.2023.03.029069 succeeded (attempt 1)
# [GPT] 	[76] 000004.2025.03.040209 succeeded (attempt 1)
# [GPT] 	[91] 000005.2019.08.000030 succeeded (attempt 1)
# [GPT] 	[70] 000004.2024.09.037809 succeeded (attempt 1)
# [GPT] 	[100] 000005.2021.01.013078 succeeded (attempt 1)
# [GPT] 	[112] 000005.2022.07.024610 succeeded (attempt 1)
# [GPT] 	[117] 000005.2022.12.027769 succeeded (attempt 1)
# [GPT] 	[96] 000005.2020.05.009054 succeeded (attempt 1)
# [GPT] 	[87] 000004.2025.10.042899 succeeded (attempt 1)
# [GPT] 	[99] 000005.2020.12.015675 succeeded (attempt 1)
# [GPT] 	[69] 000004.2024.08.037249 succeeded (attempt 1)
# [GPT] 	[101] 000005.2021.07.015539 succeeded (attempt 1)
# [GPT] 	[114] 000005.2022.09.025409 succeeded (attempt 1)
# [GPT] 	[111] 000005.2022.06.024163 succeeded (attempt 1)
# [GPT] 	[98] 000005.2020.11.014430 succeeded (attempt 1)
# [GPT] 	[105] 000005.2022.02.021050 succeeded (attempt 1)
# [GPT] 	[103] 000005.2021.11.020227 succeeded (attempt 1)
# [GPT] 	[107] 000005.2022.03.021781 succeeded (attempt 1)
# [GPT] 	[85] 000004.2025.09.042232 succeeded (attempt 1)
# [GPT] 	[122] 000005.2023.05.029953 succeeded (attempt 1)
# [GPT] 	[113] 000005.2022.08.024965 succeeded (attempt 1)
# [GPT] 	[123] 000005.2023.06.030389 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 6 before 2017-2
# [GPT] 	[118] 000005.2023.01.028070 succeeded (attempt 1)
# [GPT] 	[110] 000005.2022.05.023683 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 7 before 2018-2
# [RAG] 	No prior notes found for SID 7 before 2018-2
# [RAG] 	No prior notes found for SID 7 before 2018-2
# [RAG] 	No prior notes found for SID 7 before 2018-2
# [RAG] 	No prior notes found for SID 7 before 2018-2
# [RAG] 	No prior notes found for SID 7 before 2018-2
# [RAG] 	No prior notes found for SID 7 before 2018-2
# [GPT] 	[92] 000005.2019.08.006908 succeeded (attempt 1)
# [GPT] 	[108] 000005.2022.03.021821 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 7 before 2018-2
# [RAG] 	No prior notes found for SID 8 before 2017-8
# [RAG] 	No prior notes found for SID 8 before 2017-8
# [RAG] 	No prior notes found for SID 8 before 2017-8
# [GPT] 	[77] 000004.2025.04.040500 succeeded (attempt 1)
# [GPT] 	[78] 000004.2025.05.040904 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 9 before 2013-3
# [RAG] 	No prior notes found for SID 9 before 2013-3
# [RAG] 	No prior notes found for SID 10 before 2016-4
# [RAG] 	No prior notes found for SID 11 before 2019-9
# [GPT] 	[128] 000005.2023.11.033505 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 11 before 2019-9
# [RAG] 	No prior notes found for SID 11 before 2019-9
# [RAG] 	No prior notes found for SID 11 before 2019-9
# [GPT] 	[129] 000005.2023.12.033932 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 11 before 2019-9
# [GPT] 	[127] 000005.2023.10.033147 succeeded (attempt 1)
# [GPT] 	[115] 000005.2022.10.025990 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 11 before 2019-9
# [GPT] 	[106] 000005.2022.02.021443 succeeded (attempt 1)
# [GPT] 	[125] 000005.2023.08.031138 succeeded (attempt 1)
# [GPT] 	[119] 000005.2023.02.028516 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 11 before 2019-9
# [GPT] 	[131] 000005.2024.03.035088 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 11 before 2019-9
# [GPT] 	[133] 000005.2024.05.035995 succeeded (attempt 1)
# [GPT] 	[151] 000006.2017.02.000031 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 12 before 2016-7
# [GPT] 	[137] 000005.2024.09.037864 succeeded (attempt 1)
# [GPT] 	[152] 000006.2017.03.000032 succeeded (attempt 1)
# [GPT] 	[157] 000007.2018.02.000037 succeeded (attempt 1)
# [GPT] 	[132] 000005.2024.04.035513 succeeded (attempt 1)
# [GPT] 	[139] 000005.2024.11.038681 succeeded (attempt 1)
# [GPT] 	[147] 000005.2025.07.041743 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 13 before 2018-7
# [GPT] 	[134] 000005.2024.06.036592 succeeded (attempt 1)
# [GPT] 	[126] 000005.2023.09.032721 succeeded (attempt 1)
# [GPT] 	[116] 000005.2022.11.027421 succeeded (attempt 1)
# [GPT] 	[179] 000011.2019.09.000054 succeeded (attempt 1)
# [GPT] 	[142] 000005.2025.02.039714 succeeded (attempt 1)
# [GPT] 	[153] 000007.2018.02.000033 succeeded (attempt 1)
# [GPT] 	[166] 000008.2017.08.000041 succeeded (attempt 1)
# [GPT] 	[136] 000005.2024.08.037319 succeeded (attempt 1)
# [GPT] 	[145] 000005.2025.05.040902 succeeded (attempt 1)
# [GPT] 	[140] 000005.2024.12.038957 succeeded (attempt 1)
# [GPT] 	[143] 000005.2025.03.040205 succeeded (attempt 1)
# [GPT] 	[148] 000005.2025.08.042216 succeeded (attempt 1)
# [GPT] 	[149] 000005.2025.09.042652 succeeded (attempt 1)
# [GPT] 	[124] 000005.2023.07.030811 succeeded (attempt 1)
# [GPT] 	[163] 000007.2019.06.005673 succeeded (attempt 1)
# [GPT] 	[162] 000007.2019.06.001094 succeeded (attempt 1)
# [GPT] 	[146] 000005.2025.06.041370 succeeded (attempt 1)
# [GPT] 	[178] 000010.2016.05.000053 succeeded (attempt 1)
# [GPT] 	[158] 000007.2018.02.000038 succeeded (attempt 1)
# [GPT] 	[138] 000005.2024.10.038200 succeeded (attempt 1)
# [GPT] 	[168] 000008.2017.09.000043 succeeded (attempt 1)
# [GPT] 	[177] 000010.2016.04.000052 succeeded (attempt 1)
# [GPT] 	[130] 000005.2024.01.034187 succeeded (attempt 1)
# [GPT] 	[164] 000008.2017.08.000039 succeeded (attempt 1)
# [GPT] 	[135] 000005.2024.07.037043 succeeded (attempt 1)
# [GPT] 	[176] 000009.2013.07.000051 succeeded (attempt 1)
# [GPT] 	[167] 000008.2017.09.000042 succeeded (attempt 1)
# [GPT] 	[172] 000009.2013.03.000047 succeeded (attempt 1)
# [GPT] 	[155] 000007.2018.02.000035 succeeded (attempt 1)
# [GPT] 	[156] 000007.2018.02.000036 succeeded (attempt 1)
# [GPT] 	[141] 000005.2025.01.039259 succeeded (attempt 1)
# [GPT] 	[180] 000011.2019.09.000055 succeeded (attempt 1)
# [GPT] 	[161] 000007.2019.01.001093 succeeded (attempt 1)
# [GPT] 	[160] 000007.2018.02.001092 succeeded (attempt 1)
# [GPT] 	[182] 000011.2019.09.000057 succeeded (attempt 1)
# [GPT] 	[181] 000011.2019.09.000056 succeeded (attempt 1)
# [GPT] 	[165] 000008.2017.08.000040 succeeded (attempt 1)
# [GPT] 	[174] 000009.2013.06.000049 succeeded (attempt 1)
# [GPT] 	[144] 000005.2025.04.040617 succeeded (attempt 1)
# [GPT] 	[154] 000007.2018.02.000034 succeeded (attempt 1)
# [GPT] 	[184] 000011.2019.09.000059 succeeded (attempt 1)
# [GPT] 	[150] 000005.2025.10.042892 succeeded (attempt 1)
# [GPT] 	[170] 000008.2017.11.000045 succeeded (attempt 1)
# [GPT] 	[159] 000007.2018.02.000918 succeeded (attempt 1)
# [GPT] 	[175] 000009.2013.06.000050 succeeded (attempt 1)
# [GPT] 	[183] 000011.2019.09.000058 succeeded (attempt 1)
# [GPT] 	[187] 000012.2016.07.000060 succeeded (attempt 1)
# [GPT] 	[171] 000008.2017.12.000046 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 14 before 2018-8
# [GPT] 	[188] 000012.2016.12.000061 succeeded (attempt 1)
# [GPT] 	[169] 000008.2017.09.000044 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 14 before 2018-8
# [GPT] 	[185] 000011.2019.09.005640 succeeded (attempt 1)
# [GPT] 	[189] 000013.2018.07.000063 succeeded (attempt 1)
# [GPT] 	[173] 000009.2013.03.000048 succeeded (attempt 1)
# [GPT] 	[192] 000013.2018.08.000065 succeeded (attempt 1)
# [GPT] 	[186] 000011.2019.09.005641 succeeded (attempt 1)
# [GPT] 	[190] 000013.2018.08.000062 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 15 before 2016-5
# [GPT] 	[208] 000013.2021.06.018114 succeeded (attempt 1)
# [GPT] 	[205] 000013.2020.08.012914 succeeded (attempt 1)
# [GPT] 	[191] 000013.2018.08.000064 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 16 before 2014-3
# [GPT] 	[200] 000013.2019.08.006912 succeeded (attempt 1)
# [GPT] 	[213] 000013.2021.12.020663 succeeded (attempt 1)
# [GPT] 	[193] 000013.2019.02.003413 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 17 before 2018-9
# [RAG] 	No prior notes found for SID 17 before 2018-9
# [GPT] 	[194] 000013.2019.02.005619 succeeded (attempt 1)
# [GPT] 	[218] 000013.2022.06.023977 succeeded (attempt 1)
# [GPT] 	[232] 000013.2023.09.032706 succeeded (attempt 1)
# [GPT] 	[201] 000013.2020.07.009055 succeeded (attempt 1)
# [GPT] 	[216] 000013.2022.05.022048 succeeded (attempt 1)
# [GPT] 	[243] 000013.2024.09.038047 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 17 before 2018-9
# [GPT] 	[197] 000013.2019.05.005754 succeeded (attempt 1)
# [GPT] 	[239] 000013.2024.05.035973 succeeded (attempt 1)
# [GPT] 	[225] 000013.2023.01.028069 succeeded (attempt 1)
# [GPT] 	[207] 000013.2021.05.017091 succeeded (attempt 1)
# [GPT] 	[219] 000013.2022.07.024600 succeeded (attempt 1)
# [GPT] 	[209] 000013.2021.07.018414 succeeded (attempt 1)
# [GPT] 	[211] 000013.2021.09.019331 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 18 before 2017-2
# [RAG] 	No prior notes found for SID 18 before 2017-2
# [GPT] 	[217] 000013.2022.05.023477 succeeded (attempt 1)
# [GPT] 	[230] 000013.2023.06.030417 succeeded (attempt 1)
# [GPT] 	[195] 000013.2019.03.005625 succeeded (attempt 1)
# [GPT] 	[240] 000013.2024.06.036561 succeeded (attempt 1)
# [GPT] 	[212] 000013.2021.11.019889 succeeded (attempt 1)
# [GPT] 	[215] 000013.2022.02.021284 succeeded (attempt 1)
# [GPT] 	[227] 000013.2023.04.029055 succeeded (attempt 1)
# [GPT] 	[228] 000013.2023.05.029918 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 19 before 2019-3
# [GPT] 	[231] 000013.2023.08.031163 succeeded (attempt 1)
# [GPT] 	[206] 000013.2021.05.015685 succeeded (attempt 1)
# [GPT] 	[222] 000013.2022.10.025870 succeeded (attempt 1)
# [GPT] 	[196] 000013.2019.04.005716 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 19 before 2019-3
# [GPT] 	[233] 000013.2023.10.033159 succeeded (attempt 1)
# [GPT] 	[223] 000013.2022.11.027415 succeeded (attempt 1)
# [GPT] 	[199] 000013.2019.07.005829 succeeded (attempt 1)
# [GPT] 	[245] 000014.2018.08.000066 succeeded (attempt 1)
# [GPT] 	[203] 000013.2020.08.009218 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 19 before 2019-3
# [GPT] 	[202] 000013.2020.08.007993 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 19 before 2019-3
# [RAG] 	No prior notes found for SID 19 before 2019-3
# [GPT] 	[236] 000013.2024.01.034190 succeeded (attempt 1)
# [GPT] 	[226] 000013.2023.02.028512 succeeded (attempt 1)
# [GPT] 	[198] 000013.2019.06.005789 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 19 before 2019-3
# [GPT] 	[210] 000013.2021.08.018875 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 19 before 2019-3
# [RAG] 	No prior notes found for SID 19 before 2019-3
# [RAG] 	No prior notes found for SID 19 before 2019-3
# [GPT] 	[224] 000013.2022.12.027767 succeeded (attempt 1)
# [GPT] 	[244] 000013.2024.10.038355 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 20 before 2015-11
# [GPT] 	[237] 000013.2024.02.034570 succeeded (attempt 1)
# [GPT] 	[241] 000013.2024.07.036888 succeeded (attempt 1)
# [GPT] 	[238] 000013.2024.04.035454 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 21 before 2015-11
# [GPT] 	[247] 000014.2020.08.000068 succeeded (attempt 1)
# [GPT] 	[214] 000013.2022.01.021028 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 22 before 2017-9
# [RAG] 	No prior notes found for SID 22 before 2017-9
# [GPT] 	[248] 000014.2021.01.015969 succeeded (attempt 1)
# [GPT] 	[246] 000014.2018.08.000067 succeeded (attempt 1)
# [GPT] 	[242] 000013.2024.08.037317 succeeded (attempt 1)
# [GPT] 	[220] 000013.2022.08.024997 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 22 before 2017-9
# [RAG] 	No prior notes found for SID 23 before 2016-8
# [RAG] 	No prior notes found for SID 24 before 2014-9
# [RAG] 	No prior notes found for SID 24 before 2014-9
# [RAG] 	No prior notes found for SID 25 before 2017-8
# [GPT] 	[221] 000013.2022.09.025358 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 26 before 2017-8
# [RAG] 	No prior notes found for SID 27 before 2016-1
# [RAG] 	No prior notes found for SID 28 before 2017-3
# [RAG] 	No prior notes found for SID 28 before 2017-3
# [GPT] 	[234] 000013.2023.11.033518 succeeded (attempt 1)
# [GPT] 	[204] 000013.2020.08.012873 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 29 before 2017-8
# [RAG] 	No prior notes found for SID 29 before 2017-8
# [GPT] 	[229] 000013.2023.06.030388 succeeded (attempt 1)
# [GPT] 	[235] 000013.2023.12.033973 succeeded (attempt 1)
# [GPT] 	[255] 000017.2018.09.000076 succeeded (attempt 1)
# [GPT] 	[252] 000016.2014.03.000072 succeeded (attempt 1)
# [GPT] 	[249] 000015.2016.05.000069 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 30 before 2017-1
# [RAG] 	No prior notes found for SID 31 before 2016-6
# [GPT] 	[257] 000017.2018.11.000074 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 32 before 2016-3
# [RAG] 	No prior notes found for SID 32 before 2016-3
# [GPT] 	[261] 000018.2017.02.000079 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 32 before 2016-3
# [GPT] 	[256] 000017.2018.09.003390 succeeded (attempt 1)
# [GPT] 	[250] 000015.2016.08.000070 succeeded (attempt 1)
# [GPT] 	[277] 000022.2017.09.000095 succeeded (attempt 1)
# [GPT] 	[259] 000017.2019.08.000077 succeeded (attempt 1)
# [GPT] 	[274] 000021.2015.11.000092 succeeded (attempt 1)
# [GPT] 	[258] 000017.2018.11.003389 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 33 before 2016-5
# [GPT] 	[273] 000020.2015.12.000091 succeeded (attempt 1)
# [GPT] 	[285] 000025.2017.10.000104 succeeded (attempt 1)
# [GPT] 	[263] 000019.2019.03.000081 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 34 before 2017-5
# [GPT] 	[275] 000021.2015.12.000093 succeeded (attempt 1)
# [GPT] 	[280] 000023.2016.09.000099 succeeded (attempt 1)
# [GPT] 	[290] 000028.2017.03.000109 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 35 before 2015-12
# [GPT] 	[272] 000020.2015.11.000090 succeeded (attempt 1)
# [GPT] 	[284] 000025.2017.08.000103 succeeded (attempt 1)
# [GPT] 	[260] 000018.2017.02.000078 succeeded (attempt 1)
# [GPT] 	[268] 000019.2019.03.000086 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 35 before 2015-12
# [GPT] 	[264] 000019.2019.03.000082 succeeded (attempt 1)
# [GPT] 	[292] 000028.2017.04.000111 succeeded (attempt 1)
# [GPT] 	[288] 000027.2016.01.000107 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 35 before 2015-12
# [GPT] 	[276] 000022.2017.09.000094 succeeded (attempt 1)
# [GPT] 	[281] 000024.2014.09.000100 succeeded (attempt 1)
# [GPT] 	[287] 000026.2017.09.000106 succeeded (attempt 1)
# [GPT] 	[253] 000016.2014.05.000073 succeeded (attempt 1)
# [GPT] 	[286] 000026.2017.08.000105 succeeded (attempt 1)
# [GPT] 	[293] 000028.2017.04.000112 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 36 before 2015-10
# [GPT] 	[251] 000015.2016.08.000071 succeeded (attempt 1)
# [GPT] 	[289] 000027.2016.02.000108 succeeded (attempt 1)
# [GPT] 	[282] 000024.2014.09.000101 succeeded (attempt 1)
# [GPT] 	[307] 000030.2017.01.000118 succeeded (attempt 1)
# [GPT] 	[300] 000029.2017.12.000980 succeeded (attempt 1)
# [GPT] 	[267] 000019.2019.03.000085 succeeded (attempt 1)
# [GPT] 	[304] 000029.2018.04.002179 succeeded (attempt 1)
# [GPT] 	[306] 000029.2018.06.002247 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 37 before 2016-4
# [RAG] 	No prior notes found for SID 37 before 2016-4
# [GPT] 	[270] 000019.2019.03.000088 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 37 before 2016-4
# [GPT] 	[283] 000024.2014.10.000102 succeeded (attempt 1)
# [GPT] 	[296] 000029.2017.08.000115 succeeded (attempt 1)
# [GPT] 	[294] 000028.2017.04.000113 succeeded (attempt 1)
# [GPT] 	[309] 000031.2016.06.000120 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 38 before 2016-2
# [GPT] 	[301] 000029.2018.01.001005 succeeded (attempt 1)
# [GPT] 	[266] 000019.2019.03.000084 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 39 before 2016-5
# [GPT] 	[254] 000017.2018.09.000075 succeeded (attempt 1)
# [GPT] 	[265] 000019.2019.03.000083 succeeded (attempt 1)
# [GPT] 	[313] 000032.2016.03.000124 succeeded (attempt 1)
# [GPT] 	[308] 000030.2017.03.000119 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 40 before 2015-10
# [RAG] 	No prior notes found for SID 41 before 2017-7
# [RAG] 	No prior notes found for SID 41 before 2017-7
# [RAG] 	No prior notes found for SID 42 before 2016-11
# [GPT] 	[302] 000029.2018.02.001066 succeeded (attempt 1)
# [GPT] 	[299] 000029.2017.11.000862 succeeded (attempt 1)
# [GPT] 	[278] 000022.2017.09.000096 succeeded (attempt 1)
# [GPT] 	[271] 000019.2019.03.000089 succeeded (attempt 1)
# [GPT] 	[305] 000029.2018.05.002203 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 43 before 2016-4
# [GPT] 	[316] 000033.2016.05.000127 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 44 before 2017-9
# [RAG] 	No prior notes found for SID 44 before 2017-9
# [GPT] 	[279] 000023.2016.08.000098 succeeded (attempt 1)
# [GPT] 	[312] 000032.2016.03.000123 succeeded (attempt 1)
# [GPT] 	[297] 000029.2017.09.000116 succeeded (attempt 1)
# [GPT] 	[318] 000034.2017.05.000129 succeeded (attempt 1)
# [GPT] 	[303] 000029.2018.03.001108 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 45 before 2017-9
# [GPT] 	[310] 000031.2016.07.000121 succeeded (attempt 1)
# [GPT] 	[326] 000036.2015.10.000137 succeeded (attempt 1)
# [GPT] 	[317] 000033.2016.06.000128 succeeded (attempt 1)
# [GPT] 	[314] 000032.2016.08.000125 succeeded (attempt 1)
# [GPT] 	[319] 000034.2017.06.000130 succeeded (attempt 1)
# [GPT] 	[327] 000036.2015.11.000138 succeeded (attempt 1)
# [GPT] 	[262] 000018.2017.03.000080 succeeded (attempt 1)
# [GPT] 	[329] 000036.2015.11.000140 succeeded (attempt 1)
# [GPT] 	[331] 000037.2016.04.000142 succeeded (attempt 1)
# [GPT] 	[325] 000035.2016.03.000136 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 46 before 2017-6
# [GPT] 	[291] 000028.2017.03.000110 succeeded (attempt 1)
# [GPT] 	[337] 000037.2016.06.000148 succeeded (attempt 1)
# [GPT] 	[330] 000037.2016.04.000141 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 47 before 2016-8
# [GPT] 	[320] 000035.2015.12.000131 succeeded (attempt 1)
# [GPT] 	[343] 000040.2015.10.000154 succeeded (attempt 1)
# [GPT] 	[336] 000037.2016.06.000147 succeeded (attempt 1)
# [GPT] 	[334] 000037.2016.05.000145 succeeded (attempt 1)
# [GPT] 	[339] 000038.2016.03.000150 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 48 before 2017-9
# [GPT] 	[340] 000038.2016.03.000151 succeeded (attempt 1)
# [GPT] 	[333] 000037.2016.05.000144 succeeded (attempt 1)
# [GPT] 	[328] 000036.2015.11.000139 succeeded (attempt 1)
# [GPT] 	[295] 000029.2017.08.000114 succeeded (attempt 1)
# [GPT] 	[335] 000037.2016.05.000146 succeeded (attempt 1)
# [GPT] 	[352] 000043.2016.05.000163 succeeded (attempt 1)
# [GPT] 	[342] 000039.2016.06.000153 succeeded (attempt 1)
# [GPT] 	[344] 000040.2015.11.000155 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 48 before 2017-9
# [GPT] 	[345] 000041.2017.07.000156 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 48 before 2017-9
# [GPT] 	[323] 000035.2016.03.000134 succeeded (attempt 1)
# [GPT] 	[349] 000042.2017.01.000160 succeeded (attempt 1)
# [GPT] 	[322] 000035.2015.12.000133 succeeded (attempt 1)
# [GPT] 	[355] 000044.2017.10.000166 succeeded (attempt 1)
# [GPT] 	[361] 000045.2017.10.000170 succeeded (attempt 1)
# [GPT] 	[357] 000044.2018.01.000168 succeeded (attempt 1)
# [GPT] 	[346] 000041.2017.07.000157 succeeded (attempt 1)
# [GPT] 	[269] 000019.2019.03.000087 succeeded (attempt 1)
# [GPT] 	[354] 000044.2017.09.000165 succeeded (attempt 1)
# [GPT] 	[360] 000045.2017.09.000169 succeeded (attempt 1)
# [GPT] 	[362] 000045.2017.11.000898 succeeded (attempt 1)
# [GPT] 	[324] 000035.2016.03.000135 succeeded (attempt 1)
# [GPT] 	[364] 000045.2018.01.001021 succeeded (attempt 1)
# [GPT] 	[332] 000037.2016.04.000143 succeeded (attempt 1)
# [GPT] 	[347] 000041.2017.08.000158 succeeded (attempt 1)
# [GPT] 	[338] 000038.2016.02.000149 succeeded (attempt 1)
# [GPT] 	[311] 000032.2016.03.000122 succeeded (attempt 1)
# [GPT] 	[348] 000042.2016.11.000159 succeeded (attempt 1)
# [GPT] 	[298] 000029.2017.09.000117 succeeded (attempt 1)
# [GPT] 	[353] 000044.2017.09.000164 succeeded (attempt 1)
# [GPT] 	[358] 000044.2018.01.000887 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 49 before 2016-9
# [GPT] 	[365] 000045.2018.02.001062 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 50 before 2017-9
# [GPT] 	[359] 000044.2018.01.001009 succeeded (attempt 1)
# [GPT] 	[351] 000043.2016.04.000162 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 50 before 2017-9
# [GPT] 	[363] 000045.2017.12.000961 succeeded (attempt 1)
# [GPT] 	[356] 000044.2018.01.000167 succeeded (attempt 1)
# [GPT] 	[350] 000042.2017.03.000161 succeeded (attempt 1)
# [GPT] 	[368] 000045.2018.05.002198 succeeded (attempt 1)
# [GPT] 	[315] 000032.2016.08.000126 succeeded (attempt 1)
# [GPT] 	[371] 000045.2018.08.003359 succeeded (attempt 1)
# [GPT] 	[341] 000039.2016.05.000152 succeeded (attempt 1)
# [GPT] 	[367] 000045.2018.04.002172 succeeded (attempt 1)
# [GPT] 	[372] 000045.2018.09.003414 succeeded (attempt 1)
# [GPT] 	[377] 000047.2016.08.000173 succeeded (attempt 1)
# [GPT] 	[369] 000045.2018.06.002232 succeeded (attempt 1)
# [GPT] 	[375] 000045.2018.12.003543 succeeded (attempt 1)
# [GPT] 	[373] 000045.2018.10.003469 succeeded (attempt 1)
# [GPT] 	[378] 000047.2016.09.000174 succeeded (attempt 1)
# [GPT] 	[376] 000046.2017.06.000171 succeeded (attempt 1)
# [GPT] 	[374] 000045.2018.11.003498 succeeded (attempt 1)
# [GPT] 	[321] 000035.2015.12.000132 succeeded (attempt 1)
# [GPT] 	[382] 000048.2017.10.000178 succeeded (attempt 1)
# [GPT] 	[380] 000048.2017.09.000176 succeeded (attempt 1)
# [GPT] 	[366] 000045.2018.03.002118 succeeded (attempt 1)
# [GPT] 	[370] 000045.2018.07.002271 succeeded (attempt 1)
# [GPT] 	[379] 000048.2017.09.000175 succeeded (attempt 1)
# [GPT] 	[384] 000048.2018.01.000179 succeeded (attempt 1)
# [GPT] 	[388] 000048.2018.06.002240 succeeded (attempt 1)
# [GPT] 	[381] 000048.2017.09.000177 succeeded (attempt 1)
# [GPT] 	[383] 000048.2017.11.000895 succeeded (attempt 1)
# [GPT] 	[390] 000048.2018.08.003332 succeeded (attempt 1)
# [GPT] 	[389] 000048.2018.07.002314 succeeded (attempt 1)
# [GPT] 	[398] 000049.2016.09.000180 succeeded (attempt 1)
# [GPT] 	[394] 000048.2019.03.005646 succeeded (attempt 1)
# [GPT] 	[392] 000048.2019.01.003591 succeeded (attempt 1)
# [GPT] 	[399] 000049.2016.10.000181 succeeded (attempt 1)
# [GPT] 	[387] 000048.2018.04.002185 succeeded (attempt 1)
# [GPT] 	[400] 000050.2017.09.000185 succeeded (attempt 1)
# [GPT] 	[386] 000048.2018.02.001081 succeeded (attempt 1)
# [GPT] 	[395] 000048.2019.04.005706 succeeded (attempt 1)
# [GPT] 	[396] 000048.2019.05.005772 succeeded (attempt 1)
# [GPT] 	[413] 000050.2018.01.001036 succeeded (attempt 1)
# [GPT] 	[407] 000050.2017.11.000904 succeeded (attempt 1)
# [GPT] 	[401] 000050.2017.09.000186 succeeded (attempt 1)
# [GPT] 	[403] 000050.2017.10.000188 succeeded (attempt 1)
# [GPT] 	[414] 000050.2018.01.001037 succeeded (attempt 1)
# [GPT] 	[402] 000050.2017.10.000187 succeeded (attempt 1)
# [GPT] 	[411] 000050.2017.12.000976 succeeded (attempt 1)
# [GPT] 	[397] 000048.2019.06.005819 succeeded (attempt 1)
# [GPT] 	[404] 000050.2017.10.000189 succeeded (attempt 1)
# [GPT] 	[424] 000050.2018.04.002158 succeeded (attempt 1)
# [GPT] 	[410] 000050.2017.12.000975 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 51 before 2017-9
# [GPT] 	[412] 000050.2017.12.000977 succeeded (attempt 1)
# [GPT] 	[415] 000050.2018.02.001088 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 51 before 2017-9
# [GPT] 	[409] 000050.2017.11.000906 succeeded (attempt 1)
# [GPT] 	[423] 000050.2018.04.002157 succeeded (attempt 1)
# [GPT] 	[421] 000050.2018.03.001115 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 51 before 2017-9
# [RAG] 	No prior notes found for SID 51 before 2017-9
# [GPT] 	[418] 000050.2018.02.001091 succeeded (attempt 1)
# [GPT] 	[391] 000048.2018.11.003480 succeeded (attempt 1)
# [GPT] 	[416] 000050.2018.02.001089 succeeded (attempt 1)
# [GPT] 	[431] 000050.2018.06.002256 succeeded (attempt 1)
# [GPT] 	[385] 000048.2018.01.001053 succeeded (attempt 1)
# [GPT] 	[419] 000050.2018.03.001113 succeeded (attempt 1)
# [GPT] 	[427] 000050.2018.05.002209 succeeded (attempt 1)
# [GPT] 	[428] 000050.2018.05.002210 succeeded (attempt 1)
# [GPT] 	[405] 000050.2017.10.000190 succeeded (attempt 1)
# [GPT] 	[420] 000050.2018.03.001114 succeeded (attempt 1)
# [GPT] 	[435] 000050.2018.08.003370 succeeded (attempt 1)
# [GPT] 	[433] 000050.2018.07.002316 succeeded (attempt 1)
# [GPT] 	[432] 000050.2018.07.002315 succeeded (attempt 1)
# [GPT] 	[425] 000050.2018.04.002159 succeeded (attempt 1)
# [GPT] 	[430] 000050.2018.06.002255 succeeded (attempt 1)
# [GPT] 	[422] 000050.2018.03.001116 succeeded (attempt 1)
# [GPT] 	[417] 000050.2018.02.001090 succeeded (attempt 1)
# [GPT] 	[436] 000050.2018.08.003371 succeeded (attempt 1)
# [GPT] 	[406] 000050.2017.10.000191 succeeded (attempt 1)
# [GPT] 	[429] 000050.2018.06.002254 succeeded (attempt 1)
# [GPT] 	[393] 000048.2019.02.004608 succeeded (attempt 1)
# [GPT] 	[408] 000050.2017.11.000905 succeeded (attempt 1)
# [GPT] 	[438] 000050.2018.09.003418 succeeded (attempt 1)
# [GPT] 	[437] 000050.2018.08.003372 succeeded (attempt 1)
# [GPT] 	[442] 000050.2018.10.000184 succeeded (attempt 1)
# [GPT] 	[440] 000050.2018.10.000182 succeeded (attempt 1)
# [GPT] 	[434] 000050.2018.07.002317 succeeded (attempt 1)
# [GPT] 	[443] 000050.2018.10.003458 succeeded (attempt 1)
# [GPT] 	[446] 000050.2018.12.003550 succeeded (attempt 1)
# [GPT] 	[426] 000050.2018.05.002208 succeeded (attempt 1)
# [GPT] 	[449] 000050.2019.03.005654 succeeded (attempt 1)
# [GPT] 	[445] 000050.2018.11.003519 succeeded (attempt 1)
# [GPT] 	[447] 000050.2019.01.003580 succeeded (attempt 1)
# [GPT] 	[439] 000050.2018.09.003419 succeeded (attempt 1)
# [GPT] 	[444] 000050.2018.10.003459 succeeded (attempt 1)
# [GPT] 	[450] 000050.2019.04.005707 succeeded (attempt 1)
# [GPT] 	[452] 000050.2019.06.005808 succeeded (attempt 1)
# [GPT] 	[460] 000051.2017.10.000199 succeeded (attempt 1)
# [GPT] 	[455] 000051.2017.09.000194 succeeded (attempt 1)
# [GPT] 	[462] 000051.2017.11.000907 succeeded (attempt 1)
# [GPT] 	[451] 000050.2019.05.005766 succeeded (attempt 1)
# [GPT] 	[466] 000051.2017.12.000973 succeeded (attempt 1)
# [GPT] 	[448] 000050.2019.02.005613 succeeded (attempt 1)
# [GPT] 	[461] 000051.2017.10.000200 succeeded (attempt 1)
# [GPT] 	[465] 000051.2017.12.000972 succeeded (attempt 1)
# [GPT] 	[468] 000051.2018.01.001033 succeeded (attempt 1)
# [GPT] 	[475] 000051.2018.03.002127 succeeded (attempt 1)
# [GPT] 	[453] 000051.2017.09.000192 succeeded (attempt 1)
# [GPT] 	[476] 000051.2018.03.002128 succeeded (attempt 1)
# [GPT] 	[441] 000050.2018.10.000183 succeeded (attempt 1)
# [GPT] 	[457] 000051.2017.10.000196 succeeded (attempt 1)
# [GPT] 	[463] 000051.2017.11.000908 succeeded (attempt 1)
# [GPT] 	[458] 000051.2017.10.000197 succeeded (attempt 1)
# [GPT] 	[473] 000051.2018.02.001085 succeeded (attempt 1)
# [GPT] 	[459] 000051.2017.10.000198 succeeded (attempt 1)
# [GPT] 	[469] 000051.2018.01.001034 succeeded (attempt 1)
# [GPT] 	[454] 000051.2017.09.000193 succeeded (attempt 1)
# [GPT] 	[474] 000051.2018.02.001087 succeeded (attempt 1)
# [GPT] 	[470] 000051.2018.01.001035 succeeded (attempt 1)
# [GPT] 	[467] 000051.2017.12.000974 succeeded (attempt 1)
# [GPT] 	[480] 000051.2018.04.002161 succeeded (attempt 1)
# [GPT] 	[472] 000051.2018.02.001084 succeeded (attempt 1)
# [GPT] 	[456] 000051.2017.09.000195 succeeded (attempt 1)
# [GPT] 	[483] 000051.2018.05.002211 succeeded (attempt 1)
# [GPT] 	[487] 000051.2018.06.002258 succeeded (attempt 1)
# [GPT] 	[478] 000051.2018.03.002130 succeeded (attempt 1)[GPT] 	[481] 000051.2018.04.002162 succeeded (attempt 1)
#
# [GPT] 	[482] 000051.2018.04.002163 succeeded (attempt 1)
# [GPT] 	[492] 000051.2018.07.002321 succeeded (attempt 1)
# [GPT] 	[479] 000051.2018.04.002160 succeeded (attempt 1)
# [GPT] 	[464] 000051.2017.11.000909 succeeded (attempt 1)
# [GPT] 	[484] 000051.2018.05.002212 succeeded (attempt 1)
# [GPT] 	[495] 000051.2018.08.003364 succeeded (attempt 1)
# [GPT] 	[501] 000051.2018.10.003461 succeeded (attempt 1)
# [GPT] 	[488] 000051.2018.06.002259 succeeded (attempt 1)
# [GPT] 	[477] 000051.2018.03.002129 succeeded (attempt 1)
# [GPT] 	[485] 000051.2018.05.002213 succeeded (attempt 1)
# [GPT] 	[496] 000051.2018.08.003365 succeeded (attempt 1)
# [GPT] 	[491] 000051.2018.07.002320 succeeded (attempt 1)
# [GPT] 	[471] 000051.2018.02.001082 succeeded (attempt 1)
# [GPT] 	[498] 000051.2018.09.003401 succeeded (attempt 1)
# [GPT] 	[486] 000051.2018.06.002257 succeeded (attempt 1)
# [GPT] 	[494] 000051.2018.08.003363 succeeded (attempt 1)
# [GPT] 	[490] 000051.2018.07.002319 succeeded (attempt 1)
# [GPT] 	[497] 000051.2018.09.003400 succeeded (attempt 1)
# [GPT] 	[499] 000051.2018.09.003402 succeeded (attempt 1)
# [GPT] 	[506] 000051.2018.11.003514 succeeded (attempt 1)
# [GPT] 	[505] 000051.2018.11.003513 succeeded (attempt 1)
# [GPT] 	[509] 000051.2018.12.003547 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 52 before 2016-8
# [RAG] 	No prior notes found for SID 52 before 2016-8
# [GPT] 	[507] 000051.2018.11.003515 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 53 before 2017-9
# [GPT] 	[511] 000051.2018.12.003549 succeeded (attempt 1)
# [GPT] 	[510] 000051.2018.12.003548 succeeded (attempt 1)
# [GPT] 	[512] 000051.2019.01.003581 succeeded (attempt 1)
# [GPT] 	[500] 000051.2018.09.003403 succeeded (attempt 1)
# [GPT] 	[504] 000051.2018.11.003512 succeeded (attempt 1)
# [GPT] 	[502] 000051.2018.10.003462 succeeded (attempt 1)
# [GPT] 	[508] 000051.2018.12.003546 succeeded (attempt 1)
# [GPT] 	[513] 000051.2019.01.003582 succeeded (attempt 1)
# [GPT] 	[503] 000051.2018.10.003463 succeeded (attempt 1)
# [GPT] 	[514] 000051.2019.01.003583 succeeded (attempt 1)
# [GPT] 	[521] 000051.2019.04.005649 succeeded (attempt 1)
# [GPT] 	[517] 000051.2019.02.004600 succeeded (attempt 1)
# [GPT] 	[516] 000051.2019.02.004598 succeeded (attempt 1)
# [GPT] 	[531] 000051.2019.07.005832 succeeded (attempt 1)
# [GPT] 	[489] 000051.2018.07.002318 succeeded (attempt 1)
# [GPT] 	[515] 000051.2019.01.003584 succeeded (attempt 1)
# [GPT] 	[519] 000051.2019.02.004612 succeeded (attempt 1)
# [GPT] 	[527] 000051.2019.05.005764 succeeded (attempt 1)
# [GPT] 	[525] 000051.2019.05.005762 succeeded (attempt 1)
# [GPT] 	[537] 000051.2019.09.007979 succeeded (attempt 1)
# [GPT] 	[550] 000051.2020.07.011692 succeeded (attempt 1)
# [GPT] 	[546] 000051.2020.06.011406 succeeded (attempt 1)
# [GPT] 	[535] 000051.2019.08.006903 succeeded (attempt 1)
# [GPT] 	[493] 000051.2018.08.003362 succeeded (attempt 1)
# [GPT] 	[528] 000051.2019.06.005805 succeeded (attempt 1)
# [GPT] 	[532] 000051.2019.07.005833 succeeded (attempt 1)
# [GPT] 	[523] 000051.2019.04.005651 succeeded (attempt 1)
# [GPT] 	[530] 000051.2019.06.005807 succeeded (attempt 1)
# [GPT] 	[558] 000052.2016.08.000201 succeeded (attempt 1)
# [GPT] 	[518] 000051.2019.02.004601 succeeded (attempt 1)
# [GPT] 	[529] 000051.2019.06.005806 succeeded (attempt 1)
# [GPT] 	[536] 000051.2019.09.007978 succeeded (attempt 1)
# [GPT] 	[524] 000051.2019.04.005652 succeeded (attempt 1)
# [GPT] 	[522] 000051.2019.04.005650 succeeded (attempt 1)
# [GPT] 	[541] 000051.2019.12.009177 succeeded (attempt 1)
# [GPT] 	[538] 000051.2019.10.009041 succeeded (attempt 1)
# [GPT] 	[534] 000051.2019.08.006902 succeeded (attempt 1)
# [GPT] 	[562] 000053.2017.09.000205 succeeded (attempt 1)
# [GPT] 	[553] 000051.2020.09.013003 succeeded (attempt 1)
# [GPT] 	[559] 000052.2016.08.000202 succeeded (attempt 1)
# [GPT] 	[526] 000051.2019.05.005763 succeeded (attempt 1)
# [GPT] 	[533] 000051.2019.07.005834 succeeded (attempt 1)
# [GPT] 	[555] 000051.2020.10.014167 succeeded (attempt 1)
# [GPT] 	[520] 000051.2019.02.004613 succeeded (attempt 1)
# [GPT] 	[543] 000051.2020.02.011264 succeeded (attempt 1)
# [GPT] 	[544] 000051.2020.03.011320 succeeded (attempt 1)
# [GPT] 	[560] 000052.2016.09.000203 succeeded (attempt 1)
# [GPT] 	[565] 000053.2017.12.000992 succeeded (attempt 1)
# [GPT] 	[556] 000051.2020.10.014168 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 54 before 2017-8
# [RAG] 	No prior notes found for SID 54 before 2017-8
# [RAG] 	No prior notes found for SID 54 before 2017-8
# [GPT] 	[563] 000053.2017.10.000206 succeeded (attempt 1)
# [GPT] 	[551] 000051.2020.08.011817 succeeded (attempt 1)
# [GPT] 	[542] 000051.2020.01.009197 succeeded (attempt 1)
# [GPT] 	[545] 000051.2020.05.011501 succeeded (attempt 1)
# [GPT] 	[549] 000051.2020.06.011627 succeeded (attempt 1)
# [GPT] 	[548] 000051.2020.06.011500 succeeded (attempt 1)
# [GPT] 	[552] 000051.2020.08.011818 succeeded (attempt 1)
# [GPT] 	[567] 000053.2018.02.001078 succeeded (attempt 1)
# [GPT] 	[554] 000051.2020.09.013004 succeeded (attempt 1)
# [GPT] 	[570] 000053.2018.06.002243 succeeded (attempt 1)
# [GPT] 	[574] 000053.2018.11.003484 succeeded (attempt 1)
# [GPT] 	[577] 000053.2019.03.005664 succeeded (attempt 1)
# [GPT] 	[576] 000053.2019.02.005618 succeeded (attempt 1)
# [GPT] 	[571] 000053.2018.06.002252 succeeded (attempt 1)
# [GPT] 	[568] 000053.2018.04.002186 succeeded (attempt 1)
# [GPT] 	[539] 000051.2019.11.009102 succeeded (attempt 1)
# [GPT] 	[572] 000053.2018.07.002313 succeeded (attempt 1)
# [GPT] 	[573] 000053.2018.08.003333 succeeded (attempt 1)
# [GPT] 	[561] 000052.2016.09.000204 succeeded (attempt 1)
# [GPT] 	[540] 000051.2019.12.009148 succeeded (attempt 1)
# [GPT] 	[579] 000053.2019.04.005711 succeeded (attempt 1)
# [GPT] 	[580] 000053.2019.04.005712 succeeded (attempt 1)
# [GPT] 	[588] 000054.2017.08.000209 succeeded (attempt 1)
# [GPT] 	[581] 000053.2019.06.005809 succeeded (attempt 1)
# [GPT] 	[578] 000053.2019.03.005665 succeeded (attempt 1)
# [GPT] 	[575] 000053.2019.01.003575 succeeded (attempt 1)
# [GPT] 	[564] 000053.2017.12.000207 succeeded (attempt 1)
# [GPT] 	[583] 000053.2019.08.006891 succeeded (attempt 1)
# [GPT] 	[584] 000053.2019.10.009045 succeeded (attempt 1)
# [GPT] 	[582] 000053.2019.07.005858 succeeded (attempt 1)
# [GPT] 	[557] 000051.2020.11.014390 succeeded (attempt 1)
# [GPT] 	[566] 000053.2018.01.001054 succeeded (attempt 1)
# [GPT] 	[585] 000053.2019.11.009125 succeeded (attempt 1)
# [GPT] 	[586] 000053.2019.12.009135 succeeded (attempt 1)
# [GPT] 	[569] 000053.2018.05.002187 succeeded (attempt 1)
# [GPT] 	[599] 000054.2018.07.000870 succeeded (attempt 1)
# [GPT] 	[597] 000054.2017.11.000868 succeeded (attempt 1)
# [GPT] 	[595] 000054.2017.11.000866 succeeded (attempt 1)
# [GPT] 	[600] 000054.2018.07.002296 succeeded (attempt 1)
# [GPT] 	[589] 000054.2017.08.000210 succeeded (attempt 1)
# [GPT] 	[590] 000054.2017.09.000211 succeeded (attempt 1)
# [GPT] 	[591] 000054.2017.09.000212 succeeded (attempt 1)
# [GPT] 	[611] 000054.2019.09.007990 succeeded (attempt 1)
# [GPT] 	[601] 000054.2018.07.002298 succeeded (attempt 1)
# [GPT] 	[547] 000051.2020.06.011407 succeeded (attempt 1)
# [GPT] 	[598] 000054.2017.11.000869 succeeded (attempt 1)
# [GPT] 	[615] 000054.2019.10.009051 succeeded (attempt 1)
# [GPT] 	[596] 000054.2017.11.000867 succeeded (attempt 1)
# [GPT] 	[604] 000054.2019.06.005667 succeeded (attempt 1)
# [GPT] 	[622] 000054.2020.02.010246 succeeded (attempt 1)
# [GPT] 	[609] 000054.2019.08.006906 succeeded (attempt 1)
# [GPT] 	[605] 000054.2019.06.005717 succeeded (attempt 1)
# [GPT] 	[587] 000054.2017.08.000208 succeeded (attempt 1)
# [GPT] 	[602] 000054.2018.07.002299 succeeded (attempt 1)
# [GPT] 	[610] 000054.2019.08.006907 succeeded (attempt 1)
# [GPT] 	[612] 000054.2019.09.007991 succeeded (attempt 1)
# [GPT] 	[592] 000054.2017.09.000213 succeeded (attempt 1)
# [GPT] 	[608] 000054.2019.07.005853 succeeded (attempt 1)
# [GPT] 	[621] 000054.2020.02.010245 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 55 before 2015-10
# [GPT] 	[594] 000054.2017.11.000865 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 56 before 2016-1
# [GPT] 	[616] 000054.2019.11.009116 succeeded (attempt 1)
# [GPT] 	[593] 000054.2017.11.000864 succeeded (attempt 1)
# [GPT] 	[603] 000054.2019.06.005666 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 57 before 2019-11
# [RAG] 	No prior notes found for SID 57 before 2019-11
# [GPT] 	[606] 000054.2019.06.005813 succeeded (attempt 1)
# [GPT] 	[617] 000054.2019.12.009178 succeeded (attempt 1)
# [GPT] 	[623] 000054.2020.03.011293 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 57 before 2019-11
# [RAG] 	No prior notes found for SID 57 before 2019-11
# [RAG] 	No prior notes found for SID 57 before 2019-11
# [RAG] 	No prior notes found for SID 57 before 2019-11
# [RAG] 	No prior notes found for SID 57 before 2019-11
# [RAG] 	No prior notes found for SID 57 before 2019-11
# [GPT] 	[614] 000054.2019.10.009050 succeeded (attempt 1)
# [GPT] 	[613] 000054.2019.09.007992 succeeded (attempt 1)
# [GPT] 	[607] 000054.2019.07.005814 succeeded (attempt 1)
# [GPT] 	[619] 000054.2019.12.009180 succeeded (attempt 1)
# [GPT] 	[624] 000054.2020.04.011422 succeeded (attempt 1)
# [GPT] 	[618] 000054.2019.12.009179 succeeded (attempt 1)
# [GPT] 	[625] 000054.2020.04.011423 succeeded (attempt 1)
# [GPT] 	[620] 000054.2020.01.009213 succeeded (attempt 1)
# [GPT] 	[626] 000054.2020.05.011484 succeeded (attempt 1)
# [GPT] 	[630] 000054.2020.07.011695 succeeded (attempt 1)
# [GPT] 	[629] 000054.2020.06.011623 succeeded (attempt 1)
# [GPT] 	[628] 000054.2020.05.011486 succeeded (attempt 1)
# [GPT] 	[627] 000054.2020.05.011485 succeeded (attempt 1)
# [GPT] 	[632] 000054.2020.09.013053 succeeded (attempt 1)
# [GPT] 	[636] 000054.2020.12.015721 succeeded (attempt 1)
# [GPT] 	[640] 000054.2021.09.018099 succeeded (attempt 1)
# [GPT] 	[635] 000054.2020.11.014340 succeeded (attempt 1)
# [GPT] 	[645] 000054.2022.05.023627 succeeded (attempt 1)
# [GPT] 	[639] 000054.2021.06.018097 succeeded (attempt 1)
# [GPT] 	[634] 000054.2020.10.013154 succeeded (attempt 1)
# [GPT] 	[654] 000055.2015.10.000214 succeeded (attempt 1)
# [GPT] 	[633] 000054.2020.10.013153 succeeded (attempt 1)
# [GPT] 	[660] 000057.2019.11.000220 succeeded (attempt 1)
# [GPT] 	[657] 000056.2016.01.000217 succeeded (attempt 1)
# [GPT] 	[648] 000054.2022.08.024936 succeeded (attempt 1)
# [GPT] 	[655] 000055.2015.12.000215 succeeded (attempt 1)
# [GPT] 	[638] 000054.2021.01.015930 succeeded (attempt 1)
# [GPT] 	[643] 000054.2022.05.023625 succeeded (attempt 1)
# [GPT] 	[646] 000054.2022.06.024137 succeeded (attempt 1)
# [GPT] 	[642] 000054.2022.05.018841 succeeded (attempt 1)
# [GPT] 	[641] 000054.2021.11.018098 succeeded (attempt 1)
# [GPT] 	[658] 000056.2016.02.000218 succeeded (attempt 1)
# [GPT] 	[652] 000054.2022.12.027878 succeeded (attempt 1)
# [GPT] 	[649] 000054.2022.09.025430 succeeded (attempt 1)
# [GPT] 	[647] 000054.2022.07.024544 succeeded (attempt 1)
# [GPT] 	[631] 000054.2020.08.011797 succeeded (attempt 1)
# [GPT] 	[662] 000057.2019.11.000222 succeeded (attempt 1)
# [GPT] 	[656] 000055.2015.12.000216 succeeded (attempt 1)
# [GPT] 	[653] 000054.2023.02.028643 succeeded (attempt 1)
# [GPT] 	[651] 000054.2022.11.027458 succeeded (attempt 1)
# [GPT] 	[659] 000057.2019.11.000219 succeeded (attempt 1)
# [GPT] 	[666] 000057.2019.11.000226 succeeded (attempt 1)
# [GPT] 	[665] 000057.2019.11.000225 succeeded (attempt 1)
# [GPT] 	[650] 000054.2022.10.025895 succeeded (attempt 1)
# [GPT] 	[663] 000057.2019.11.000223 succeeded (attempt 1)
# [GPT] 	[644] 000054.2022.05.023626 succeeded (attempt 1)
# [GPT] 	[668] 000057.2020.09.011732 succeeded (attempt 1)
# [GPT] 	[675] 000057.2021.04.016659 succeeded (attempt 1)
# [GPT] 	[664] 000057.2019.11.000224 succeeded (attempt 1)
# [GPT] 	[669] 000057.2020.09.012995 succeeded (attempt 1)
# [GPT] 	[637] 000054.2020.12.015722 succeeded (attempt 1)
# [GPT] 	[672] 000057.2020.12.015630 succeeded (attempt 1)
# [GPT] 	[670] 000057.2020.10.014211 succeeded (attempt 1)
# [GPT] 	[661] 000057.2019.11.000221 succeeded (attempt 1)
# [GPT] 	[677] 000057.2021.04.017139 succeeded (attempt 1)
# [GPT] 	[686] 000057.2021.12.020602 succeeded (attempt 1)
# [GPT] 	[671] 000057.2020.11.014383 succeeded (attempt 1)
# [GPT] 	[678] 000057.2021.05.017535 succeeded (attempt 1)
# [GPT] 	[680] 000057.2021.07.018415 succeeded (attempt 1)
# [GPT] 	[683] 000057.2021.10.019821 succeeded (attempt 1)
# [GPT] 	[681] 000057.2021.08.018817 succeeded (attempt 1)
# [GPT] 	[674] 000057.2021.02.016220 succeeded (attempt 1)
# [GPT] 	[679] 000057.2021.06.018029 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 58 before 2017-8
# [RAG] 	No prior notes found for SID 58 before 2017-8
# [RAG] 	No prior notes found for SID 59 before 2016-5
# [RAG] 	No prior notes found for SID 59 before 2016-5
# [GPT] 	[682] 000057.2021.09.019349 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 60 before 2019-3
# [GPT] 	[676] 000057.2021.04.017138 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 60 before 2019-3
# [RAG] 	No prior notes found for SID 60 before 2019-3
# [GPT] 	[684] 000057.2021.11.020312 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 60 before 2019-3
# [RAG] 	No prior notes found for SID 60 before 2019-3
# [RAG] 	No prior notes found for SID 60 before 2019-3
# [RAG] 	No prior notes found for SID 60 before 2019-3
# [RAG] 	No prior notes found for SID 60 before 2019-3
# [RAG] 	No prior notes found for SID 60 before 2019-3
# [GPT] 	[692] 000057.2022.06.024174 succeeded (attempt 1)
# [GPT] 	[687] 000057.2022.01.020895 succeeded (attempt 1)
# [GPT] 	[689] 000057.2022.03.021862 succeeded (attempt 1)
# [GPT] 	[701] 000057.2023.12.033948 succeeded (attempt 1)
# [GPT] 	[688] 000057.2022.02.021310 succeeded (attempt 1)
# [GPT] 	[694] 000057.2022.08.024938 succeeded (attempt 1)
# [GPT] 	[698] 000057.2023.09.032744 succeeded (attempt 1)
# [GPT] 	[693] 000057.2022.07.024531 succeeded (attempt 1)
# [GPT] 	[697] 000057.2023.08.031236 succeeded (attempt 1)
# [GPT] 	[702] 000057.2024.01.034270 succeeded (attempt 1)
# [GPT] 	[685] 000057.2021.12.020600 succeeded (attempt 1)
# [GPT] 	[699] 000057.2023.10.033163 succeeded (attempt 1)
# [GPT] 	[700] 000057.2023.12.033773 succeeded (attempt 1)
# [GPT] 	[706] 000057.2024.06.036046 succeeded (attempt 1)
# [GPT] 	[705] 000057.2024.04.035442 succeeded (attempt 1)
# [GPT] 	[714] 000057.2025.02.039831 succeeded (attempt 1)
# [GPT] 	[673] 000057.2021.01.015928 succeeded (attempt 1)
# [GPT] 	[695] 000057.2022.09.025521 succeeded (attempt 1)
# [GPT] 	[724] 000058.2017.08.000228 succeeded (attempt 1)
# [GPT] 	[667] 000057.2020.07.009118 succeeded (attempt 1)
# [GPT] 	[704] 000057.2024.03.034994 succeeded (attempt 1)
# [GPT] 	[696] 000057.2023.04.029557 succeeded (attempt 1)
# [GPT] 	[708] 000057.2024.07.036973 succeeded (attempt 1)
# [GPT] 	[707] 000057.2024.06.036554 succeeded (attempt 1)
# [GPT] 	[726] 000058.2017.09.000230 succeeded (attempt 1)
# [GPT] 	[710] 000057.2024.09.037888 succeeded (attempt 1)
# [GPT] 	[703] 000057.2024.02.034714 succeeded (attempt 1)
# [GPT] 	[722] 000057.2025.10.042998 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 61 before 2015-10
# [GPT] 	[717] 000057.2025.05.041016 succeeded (attempt 1)
# ...
# [GPT] 	[27880] 003321.2025.06.041266 succeeded (attempt 1)
# [GPT] 	[27888] 003322.2025.08.042094 succeeded (attempt 1)
# [GPT] 	[27903] 003325.2025.05.040641 succeeded (attempt 1)
# [GPT] 	[27882] 003321.2025.08.042099 succeeded (attempt 1)
# [GPT] 	[27876] 003320.2025.08.042098 succeeded (attempt 1)
# [GPT] 	[27900] 003324.2025.07.041755 succeeded (attempt 1)
# [GPT] 	[27877] 003320.2025.09.042687 succeeded (attempt 1)
# [GPT] 	[27827] 003313.2025.09.042650 succeeded (attempt 1)
# [GPT] 	[27878] 003320.2025.10.042991 succeeded (attempt 1)
# [GPT] 	[27730] 003291.2025.05.041196 succeeded (attempt 1)
# [GPT] 	[27910] 003326.2025.07.041007 succeeded (attempt 1)
# [GPT] 	[27907] 003325.2025.09.042629 succeeded (attempt 1)
# [GPT] 	[27831] 003314.2025.05.041175 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3333 before 2025-6
# [RAG] 	No prior notes found for SID 3334 before 2025-7
# [GPT] 	[27890] 003322.2025.10.042968 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3335 before 2025-5
# [GPT] 	[27895] 003323.2025.09.042685 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3335 before 2025-5
# [RAG] 	No prior notes found for SID 3335 before 2025-5
# [RAG] 	No prior notes found for SID 3335 before 2025-5
# [GPT] 	[27911] 003326.2025.07.041474 succeeded (attempt 1)
# [GPT] 	[27837] 003315.2025.04.040518 succeeded (attempt 1)
# [GPT] 	[27886] 003322.2025.06.041262 succeeded (attempt 1)
# [GPT] 	[27844] 003315.2025.06.041484 succeeded (attempt 1)
# [GPT] 	[27896] 003323.2025.10.042986 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3336 before 2025-5
# [GPT] 	[27914] 003326.2025.10.042636 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3337 before 2025-8
# [RAG] 	No prior notes found for SID 3338 before 2025-5
# [GPT] 	[27892] 003323.2025.06.041264 succeeded (attempt 1)
# [GPT] 	[27916] 003327.2025.04.040780 succeeded (attempt 1)
# [GPT] 	[27920] 003328.2025.06.040809 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3339 before 2025-7
# [GPT] 	[27905] 003325.2025.07.041468 succeeded (attempt 1)
# [GPT] 	[27885] 003322.2025.04.040552 succeeded (attempt 1)
# [GPT] 	[27917] 003327.2025.06.041305 succeeded (attempt 1)
# [GPT] 	[27918] 003327.2025.06.041396 succeeded (attempt 1)
# [GPT] 	[27913] 003326.2025.09.042273 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3340 before 2025-5
# [GPT] 	[27919] 003327.2025.07.041769 succeeded (attempt 1)
# [GPT] 	[27909] 003325.2025.10.043014 succeeded (attempt 1)
# [GPT] 	[27850] 003315.2025.09.042630 succeeded (attempt 1)
# [GPT] 	[27865] 003318.2025.09.042680 succeeded (attempt 1)
# [GPT] 	[27935] 003332.2025.08.042299 succeeded (attempt 1)
# [GPT] 	[27851] 003315.2025.09.042736 succeeded (attempt 1)
# [GPT] 	[27894] 003323.2025.08.042096 succeeded (attempt 1)
# [GPT] 	[27938] 003332.2025.09.042548 succeeded (attempt 1)
# [GPT] 	[27924] 003332.2025.05.041147 succeeded (attempt 1)
# [GPT] 	[27945] 003335.2025.05.040964 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3342 before 2025-9
# [RAG] 	No prior notes found for SID 3343 before 2025-9
# [GPT] 	[27942] 003332.2025.10.043053 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3344 before 2025-10
# [RAG] 	No prior notes found for SID 3345 before 2025-7
# [GPT] 	[27952] 003336.2025.05.041076 succeeded (attempt 1)
# [GPT] 	[27946] 003335.2025.05.040965 succeeded (attempt 1)
# [GPT] 	[27928] 003332.2025.06.041600 succeeded (attempt 1)
# [GPT] 	[27936] 003332.2025.08.042398 succeeded (attempt 1)
# [GPT] 	[27934] 003332.2025.08.042178 succeeded (attempt 1)
# [GPT] 	[27926] 003332.2025.06.041409 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3346 before 2025-7
# [GPT] 	[27927] 003332.2025.06.041525 succeeded (attempt 1)
# [GPT] 	[27846] 003315.2025.07.041720 succeeded (attempt 1)
# [GPT] 	[27904] 003325.2025.06.041000 succeeded (attempt 1)
# [GPT] 	[27948] 003335.2025.05.041029 succeeded (attempt 1)
# [GPT] 	[27937] 003332.2025.09.042452 succeeded (attempt 1)
# [GPT] 	[27949] 003335.2025.06.041511 succeeded (attempt 1)
# [GPT] 	[27947] 003335.2025.05.040991 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3347 before 2025-8
# [RAG] 	No prior notes found for SID 3347 before 2025-8
# [GPT] 	[27899] 003324.2025.06.041585 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3347 before 2025-8
# [RAG] 	No prior notes found for SID 3348 before 2025-7
# [GPT] 	[27939] 003332.2025.09.042699 succeeded (attempt 1)
# [GPT] 	[27931] 003332.2025.07.041974 succeeded (attempt 1)
# [GPT] 	[27923] 003332.2025.05.041052 succeeded (attempt 1)
# [GPT] 	[27941] 003332.2025.10.042894 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3349 before 2025-9
# [GPT] 	[27930] 003332.2025.07.041921 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3351 before 2025-6
# [RAG] 	No prior notes found for SID 3352 before 2025-6
# [GPT] 	[27929] 003332.2025.07.041672 succeeded (attempt 1)
# [GPT] 	[27953] 003336.2025.09.042649 succeeded (attempt 1)
# [GPT] 	[27940] 003332.2025.09.042755 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3352 before 2025-6
# [GPT] 	[27912] 003326.2025.08.041865 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3352 before 2025-6
# [RAG] 	No prior notes found for SID 3352 before 2025-6
# [GPT] 	[27932] 003332.2025.07.042017 succeeded (attempt 1)
# [GPT] 	[27921] 003328.2025.08.042284 succeeded (attempt 1)
# [GPT] 	[27954] 003337.2025.08.042320 succeeded (attempt 1)
# [GPT] 	[27902] 003324.2025.10.043024 succeeded (attempt 1)
# [GPT] 	[27933] 003332.2025.08.042079 succeeded (attempt 1)
# [GPT] 	[27906] 003325.2025.08.041858 succeeded (attempt 1)
# [GPT] 	[27958] 003339.2025.07.041849 succeeded (attempt 1)
# [GPT] 	[27959] 003339.2025.09.042463 succeeded (attempt 1)
# [GPT] 	[27956] 003338.2025.06.041500 succeeded (attempt 1)
# [GPT] 	[27951] 003335.2025.09.042160 succeeded (attempt 1)
# [GPT] 	[27960] 003339.2025.09.042815 succeeded (attempt 1)
# [GPT] 	[27950] 003335.2025.07.041894 succeeded (attempt 1)
# [GPT] 	[27944] 003334.2025.07.041844 succeeded (attempt 1)
# [GPT] 	[27963] 003340.2025.07.041758 succeeded (attempt 1)
# [GPT] 	[27961] 003340.2025.05.041005 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3353 before 2025-7
# [GPT] 	[27908] 003325.2025.10.042267 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3354 before 2025-7
# [GPT] 	[27922] 003332.2025.05.040898 succeeded (attempt 1)
# [GPT] 	[27864] 003318.2025.08.042093 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3355 before 2025-6
# [GPT] 	[27967] 003343.2025.09.041145 succeeded (attempt 1)
# [GPT] 	[27964] 003340.2025.08.042170 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3356 before 2025-7
# [GPT] 	[27965] 003340.2025.10.043025 succeeded (attempt 1)
# [GPT] 	[27957] 003338.2025.09.042319 succeeded (attempt 1)
# [GPT] 	[27969] 003345.2025.07.041765 succeeded (attempt 1)
# [GPT] 	[27976] 003346.2025.09.042523 succeeded (attempt 1)
# [GPT] 	[27875] 003320.2025.07.041753 succeeded (attempt 1)
# [GPT] 	[27970] 003345.2025.08.042124 succeeded (attempt 1)
# [GPT] 	[27989] 003352.2025.06.041381 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3357 before 2025-7
# [GPT] 	[27962] 003340.2025.06.041586 succeeded (attempt 1)
# [GPT] 	[27973] 003346.2025.07.041822 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3358 before 2025-7
# [GPT] 	[27980] 003347.2025.08.042125 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3359 before 2025-7
# [GPT] 	[27981] 003347.2025.08.042327 succeeded (attempt 1)
# [GPT] 	[27966] 003342.2025.09.041144 succeeded (attempt 1)
# [GPT] 	[27985] 003348.2025.09.042522 succeeded (attempt 1)
# [GPT] 	[27988] 003352.2025.06.041293 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3360 before 2025-9
# [GPT] 	[27972] 003345.2025.09.042524 succeeded (attempt 1)
# [GPT] 	[27971] 003345.2025.08.042326 succeeded (attempt 1)
# [GPT] 	[27982] 003347.2025.09.042525 succeeded (attempt 1)
# [GPT] 	[28000] 003352.2025.09.042762 succeeded (attempt 1)
# [GPT] 	[28002] 003352.2025.10.042932 succeeded (attempt 1)
# [GPT] 	[27990] 003352.2025.06.041540 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3362 before 2025-6
# [GPT] 	[27991] 003352.2025.06.041589 succeeded (attempt 1)
# [GPT] 	[28007] 003354.2025.07.041340 succeeded (attempt 1)
# [GPT] 	[27968] 003344.2025.10.041191 succeeded (attempt 1)
# [GPT] 	[27974] 003346.2025.09.042123 succeeded (attempt 1)
# [GPT] 	[27986] 003349.2025.09.042168 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3362 before 2025-6
# [GPT] 	[27994] 003352.2025.08.042131 succeeded (attempt 1)
# [GPT] 	[27915] 003326.2025.10.043021 succeeded (attempt 1)
# [GPT] 	[27975] 003346.2025.09.042325 succeeded (attempt 1)
# [GPT] 	[27881] 003321.2025.07.041754 succeeded (attempt 1)
# [GPT] 	[28005] 003353.2025.09.042658 succeeded (attempt 1)
# [GPT] 	[28008] 003354.2025.09.042310 succeeded (attempt 1)
# [GPT] 	[27997] 003352.2025.09.042438 succeeded (attempt 1)
# [GPT] 	[27999] 003352.2025.09.042589 succeeded (attempt 1)
# [GPT] 	[27996] 003352.2025.08.042297 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3363 before 2025-7
# [GPT] 	[27995] 003352.2025.08.042188 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3364 before 2025-7
# [RAG] 	No prior notes found for SID 3364 before 2025-7
# [GPT] 	[28003] 003353.2025.07.041316 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3365 before 2025-7
# [GPT] 	[28006] 003353.2025.10.043012 succeeded (attempt 1)
# [GPT] 	[27998] 003352.2025.09.042446 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3365 before 2025-7
# [GPT] 	[28013] 003355.2025.08.042171 succeeded (attempt 1)
# [GPT] 	[28001] 003352.2025.10.042819 succeeded (attempt 1)
# [GPT] 	[27993] 003352.2025.07.042012 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3366 before 2025-10
# [RAG] 	No prior notes found for SID 3367 before 2025-8
# [RAG] 	No prior notes found for SID 3368 before 2025-7
# [RAG] 	No prior notes found for SID 3370 before 2025-8
# [GPT] 	[28028] 003359.2025.09.042665 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3370 before 2025-8
# [RAG] 	No prior notes found for SID 3371 before 2025-8
# [GPT] 	[28014] 003355.2025.09.042555 succeeded (attempt 1)
# [GPT] 	[28027] 003359.2025.07.041949 succeeded (attempt 1)
# [GPT] 	[28022] 003357.2025.09.042657 succeeded (attempt 1)
# [GPT] 	[28024] 003358.2025.07.041344 succeeded (attempt 1)
# [GPT] 	[28029] 003359.2025.10.042987 succeeded (attempt 1)
# [GPT] 	[28021] 003357.2025.09.042311 succeeded (attempt 1)
# [GPT] 	[27977] 003346.2025.09.042761 succeeded (attempt 1)
# [GPT] 	[28025] 003358.2025.09.042308 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3372 before 2025-8
# [RAG] 	No prior notes found for SID 3373 before 2025-8
# [GPT] 	[27943] 003333.2025.06.040901 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3375 before 2025-9
# [GPT] 	[28031] 003362.2025.06.041550 succeeded (attempt 1)
# [GPT] 	[27925] 003332.2025.06.041284 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3376 before 2025-9
# [RAG] 	No prior notes found for SID 3377 before 2025-9
# [RAG] 	No prior notes found for SID 3377 before 2025-9
# [GPT] 	[28043] 003363.2025.07.041740 succeeded (attempt 1)
# [GPT] 	[27992] 003352.2025.07.041690 succeeded (attempt 1)
# [GPT] 	[27987] 003351.2025.06.041267 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3377 before 2025-9
# [GPT] 	[28044] 003364.2025.07.041889 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3378 before 2025-9
# [GPT] 	[28034] 003362.2025.07.041741 succeeded (attempt 1)
# [GPT] 	[28039] 003362.2025.09.042584 succeeded (attempt 1)
# [GPT] 	[28004] 003353.2025.09.042312 succeeded (attempt 1)
# [GPT] 	[27955] 003338.2025.05.041074 succeeded (attempt 1)
# [GPT] 	[28051] 003367.2025.08.041875 succeeded (attempt 1)
# [GPT] 	[28045] 003364.2025.07.041961 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3379 before 2025-9
# [RAG] 	No prior notes found for SID 3379 before 2025-9
# [GPT] 	[28035] 003362.2025.07.042044 succeeded (attempt 1)
# [GPT] 	[28054] 003368.2025.09.042686 succeeded (attempt 1)
# [GPT] 	[28046] 003364.2025.09.042526 succeeded (attempt 1)
# [GPT] 	[28050] 003366.2025.10.043008 succeeded (attempt 1)
# [GPT] 	[28026] 003358.2025.10.043023 succeeded (attempt 1)
# [GPT] 	[28058] 003370.2025.09.042482 succeeded (attempt 1)
# [GPT] 	[28037] 003362.2025.08.042355 succeeded (attempt 1)
# [GPT] 	[28036] 003362.2025.08.042147 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3379 before 2025-9
# [GPT] 	[27983] 003348.2025.07.041829 succeeded (attempt 1)
# [GPT] 	[28056] 003370.2025.08.042193 succeeded (attempt 1)
# [GPT] 	[28057] 003370.2025.08.042339 succeeded (attempt 1)
# [GPT] 	[28033] 003362.2025.07.041712 succeeded (attempt 1)
# [GPT] 	[27984] 003348.2025.08.042122 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3380 before 2025-9
# [GPT] 	[28061] 003371.2025.09.042510 succeeded (attempt 1)
# [GPT] 	[27979] 003347.2025.08.041763 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3384 before 2025-9
# [GPT] 	[28040] 003362.2025.09.042770 succeeded (attempt 1)
# [GPT] 	[28041] 003362.2025.10.042849 succeeded (attempt 1)
# [GPT] 	[28042] 003362.2025.10.042948 succeeded (attempt 1)
# [GPT] 	[28067] 003373.2025.08.042285 succeeded (attempt 1)
# [GPT] 	[28016] 003356.2025.07.041342 succeeded (attempt 1)
# [RAG] 	No prior notes found for SID 3386 before 2025-10
# [RAG] 	No prior notes found for SID 3386 before 2025-10
# [GPT] 	[28053] 003368.2025.08.042097 succeeded (attempt 1)
# [GPT] 	[28048] 003365.2025.07.041960 succeeded (attempt 1)
# [GPT] 	[28062] 003371.2025.09.042646 succeeded (attempt 1)
# [GPT] 	[28059] 003370.2025.10.042877 succeeded (attempt 1)
# [GPT] 	[28020] 003357.2025.07.041343 succeeded (attempt 1)
# [GPT] 	[28066] 003372.2025.09.042751 succeeded (attempt 1)
# [GPT] 	[27978] 003346.2025.10.042903 succeeded (attempt 1)
# [GPT] 	[28063] 003371.2025.09.042742 succeeded (attempt 1)
# [GPT] 	[28047] 003365.2025.07.041890 succeeded (attempt 1)
# [GPT] 	[28065] 003372.2025.08.042198 succeeded (attempt 1)
# [GPT] 	[28009] 003354.2025.09.042655 succeeded (attempt 1)
# [GPT] 	[28019] 003356.2025.10.043022 succeeded (attempt 1)
# [GPT] 	[28069] 003376.2025.09.042465 succeeded (attempt 1)
# [GPT] 	[28060] 003371.2025.08.042377 succeeded (attempt 1)
# [GPT] 	[28070] 003377.2025.09.042511 succeeded (attempt 1)
# [GPT] 	[28011] 003355.2025.06.041341 succeeded (attempt 1)
# [GPT] 	[28017] 003356.2025.09.042309 succeeded (attempt 1)
# [GPT] 	[28052] 003368.2025.07.041958 succeeded (attempt 1)
# [GPT] 	[28064] 003371.2025.10.042872 succeeded (attempt 1)
# [GPT] 	[28049] 003365.2025.09.042527 succeeded (attempt 1)
# [GPT] 	[28072] 003377.2025.09.042735 succeeded (attempt 1)
# [GPT] 	[28038] 003362.2025.09.042456 succeeded (attempt 1)
# [GPT] 	[28010] 003354.2025.10.043020 succeeded (attempt 1)
# [GPT] 	[28015] 003355.2025.10.043026 succeeded (attempt 1)
# [GPT] 	[28075] 003378.2025.10.042969 succeeded (attempt 1)
# [GPT] 	[28080] 003380.2025.09.042766 succeeded (attempt 1)
# [GPT] 	[28074] 003378.2025.09.042539 succeeded (attempt 1)
# [GPT] 	[28030] 003360.2025.09.042664 succeeded (attempt 1)
# [GPT] 	[28081] 003384.2025.09.042781 succeeded (attempt 1)
# [GPT] 	[28018] 003356.2025.09.042654 succeeded (attempt 1)
# [GPT] 	[28076] 003379.2025.09.042622 succeeded (attempt 1)
# [GPT] 	[28083] 003384.2025.10.042921 succeeded (attempt 1)
# [GPT] 	[28012] 003355.2025.07.041759 succeeded (attempt 1)
# [GPT] 	[28077] 003379.2025.09.042733 succeeded (attempt 1)
# [GPT] 	[28086] 003386.2025.10.042935 succeeded (attempt 1)
# [GPT] 	[28078] 003379.2025.09.042811 succeeded (attempt 1)
# [GPT] 	[28079] 003379.2025.10.042857 succeeded (attempt 1)
# [GPT] 	[28085] 003386.2025.10.042841 succeeded (attempt 1)
# [GPT] 	[28082] 003384.2025.10.042828 succeeded (attempt 1)
# [GPT] 	[28023] 003357.2025.10.043019 succeeded (attempt 1)
# [GPT] 	[28055] 003368.2025.10.042989 succeeded (attempt 1)
# [GPT] 	[28032] 003362.2025.06.041623 succeeded (attempt 1)
# [GPT] 	[28068] 003375.2025.09.042813 succeeded (attempt 1)
# [GPT] 	[28071] 003377.2025.09.042626 succeeded (attempt 1)
# [GPT] 	[28073] 003377.2025.10.042860 succeeded (attempt 1)
# [GPT] 	[28084] 003384.2025.10.043067 succeeded (attempt 1)
# [DONE] 	Justification pass complete: 28087 succeeded, 0 failed.

# %%
from elasticsearch import Elasticsearch, helpers
import pandas as pd

def fetch_index_as_dataframe(es_client, index_name, scroll='2m', page_size=1000) -> pd.DataFrame:
    """
    Fetches all documents from an Elasticsearch index and returns them as a DataFrame.
    
    Parameters:
    - es_client: Elasticsearch client instance (e.g., pipeline.conn.es_client)
    - index_name: Name of the index to retrieve
    - scroll: Scroll duration to keep context alive
    - page_size: Number of documents per scroll batch

    Returns:
    - pd.DataFrame containing all _source fields from the index
    """
    results = []

    # Initial search to get the scroll ID
    resp = es_client.search(
        index=index_name,
        scroll=scroll,
        size=page_size,
        body={"query": {"match_all": {}}}
    )

    scroll_id = resp['_scroll_id']
    hits = resp['hits']['hits']
    results.extend([doc['_source'] for doc in hits])

    # Keep scrolling until no hits are returned
    while len(hits):
        resp = es_client.scroll(scroll_id=scroll_id, scroll=scroll)
        scroll_id = resp['_scroll_id']
        hits = resp['hits']['hits']
        results.extend([doc['_source'] for doc in hits])

    # Cleanup scroll context
    es_client.clear_scroll(scroll_id=scroll_id)

    return pd.DataFrame(results)

# %%
df = fetch_index_as_dataframe(pipeline.conn.es_client, "scorecard_rag_notes")
# Out:
# /tmp/ipykernel_429/3978008377.py:20: DeprecationWarning: Received 'size' via a specific parameter in the presence of a 'body' parameter, which is deprecated and will be removed in a future version. Instead, use only 'body' or only specific parameters.
#   resp = es_client.search(

# %%
df.sample().to_dict()
# Out:
# {'SID': {27283: 2909},
#  'Scorecard_Detail_Note_SID': {27283: 40044},
#  'Scorecard_Note': {27283: 'Program security and the program are working accreditation items. Subcontract closeout to happen upon expiration of PoP on 4/1/25.'},
#  'Note_Year': {27283: 2025},
#  'Note_Month': {27283: '03'},
#  'PO_Number': {27283: '4105668131'},
#  'PO_Contract_Type': {27283: 'FFP'},
#  'PO_Complexity_Level': {27283: 3},
#  'PO_Lifecycle_Phase': {27283: 'Production'},
#  'Supplier_Name': {27283: 'FEDERAL CONTRACTING, INC.'},
#  'LM_Vendor_ID': {27283: 'LM1581528'},
#  'Supplier_Site_Location': {27283: 'COLORADO SPRINGS, CO'},
#  'Supplier_DandB_Number': {27283: '039142492'},
#  'LOB_Name': {27283: 'LMSS CENTRAL'},
#  'Program_Name': {27283: 'CIP HISTORICAL'},
#  'Prime_Contract_Number': {27283: 'I30002'},
#  'Program_Contract_Type': {27283: 'Capital'},
#  'PO_Contract_Dollars_Mil': {27283: 3371898.63},
#  'PO_Funding_Dollars_Mil': {27283: 3371898.63},
#  'PO_Definitization_Status': {27283: 'DEF'},
#  'PO_Funding_Override_Ind': {27283: 'Y'},
#  'PO_Contract_Override_Ind': {27283: 'N'},
#  'Performance_Management_Type': {27283: 'FFP'},
#  'Overall': {27283: 'G'},
#  'Technical': {27283: 'G'},
#  'Quality': {27283: 'G'},
#  'Cost': {27283: 'G'},
#  'Schedule': {27283: 'G'},
#  'LM_Dependency': {27283: 'G'},
#  'Cyber': {27283: 'Y'},
#  'Report_Month': {27283: '03'},
#  'Report_Year': {27283: '2025'},
#  'Archive_Indicator': {27283: 'Y'},
#  'sid_key': {27283: '002909.2025.03.040044'},
#  'pre_scrub_text': {27283: 'Program security and the program are working accreditation items. Subcontract closeout to happen upon expiration of PoP on 4/1/25.'},
#  'verbs': {27283: 'work happen'},
#  'adjectives': {27283: ''},
#  'noun_chunks': {27283: 'Program security the program accreditation items Subcontract closeout expiration PoP'},
#  'main_words': {27283: 'work happen program security the program accreditation items subcontract closeout expiration pop'},
#  'target': {27283: 0},
#  'next_color_code': {27283: -1},
#  'note_history': {27283: '29079;29427;29947;30318;30644;31102;32657;33052;33540;33969;34232;34597;34964;35554;36090;36584;37026;37459;37720;38206;38622;39008;39299;39701'},
#  'last_sid': {27283: '002909.2025.03.040044'},
#  'sid_key_0': {27283: '002909.2024.12.039008'},
#  'sid_key_1': {27283: '002909.2025.01.039299'},
#  'sid_key_2': {27283: '002909.2025.02.039701'},
#  'sid_key_3': {27283: '002909.2025.03.040044'},
#  'predicted_label': {27283: 0},
#  'prob_green': {27283: 0.999903870779108},
#  'prob_yellow': {27283: 9.178598605365746e-05},
#  'prob_red': {27283: 4.343234838319614e-06},
#  'all_green': {27283: 1},
#  'color_set': {27283: 'GGGG'},
#  'trainable': {27283: False},
#  'predicted_color': {27283: 'Green'},
#  'Note_YearMonth': {27283: 202503},
#  'Report_Date': {27283: '2025-03-01T00:00:00'},
#  'token_count': {27283: 29},
#  'embedding_version': {27283: 'BAAI/bge-large-en-v1.5'},
#  'gpt_justification': {27283: ''},
#  'created_at': {27283: '2025-10-07T12:25:54.768123'},
#  'justification': {27283: "The model forecasts a Green rating with 99.99% confidence for SID 2909 on the CIP HISTORICAL program.\n\nThe model likely predicted this highly favorable outcome due to several factors evident in the recent local note history for SID 2909. Firstly, the subcontractor has demonstrated consistent progress and adherence to project timelines. For instance, the note from March 2023 (Note 029079) indicates that the subcontractor successfully submitted design permits and received approval for demo permits, allowing them to begin ordering long lead items. This early stage success sets a positive tone for the project's trajectory.\n\nSecondly, the subcontractor has shown effective coordination and proactive management of security-related requirements, which are critical for the accreditation process. Notes from March 2024 (Note 034964) and April 2024 (Note 035554) highlight that construction work, including TEMPEST type work necessary for accreditation, was approved and commenced in a timely manner. Despite awaiting formal full approval from customer security, the subcontractor continued to make progress, indicating strong project management and communication skills.\n\nLastly, the subcontractor has maintained a clear focus on completing accreditation-related tasks and addressing any remaining issues promptly. The notes from December 2024 (Note 039008) and January 2025 (Note 039299) show that the subcontractor completed a pre-accreditation walk-through and is actively working on a small list of punch list items. Additionally, the February 2025 (Note 039701) and March 2025 (Note 040044) notes confirm ongoing efforts to finalize accreditation items and prepare for subcontract closeout upon the expiration of the period of performance.\n\nIn summary, the subcontractor's consistent performance, effective coordination with security teams, and proactive management of project milestones likely contributed to the model's prediction of a Green rating with 99.99% confidence. The absence of any significant issues or delays in the recent note history further supports this highly positive forecast."}}

# %%
df['justification'].isna().sum()
# Out:
# 0

# %%
# Clean up DataFrame for export - remove embeddings but keep H1 and H2 prediction columns
df = df.dropna(subset=['justification'])
exclude_cols = ['embedding', 'tokens', 'text_for_embedding']
df = df[[x for x in df.columns if x not in exclude_cols]]

# Verify H2 columns are present
h2_cols = [c for c in df.columns if '_h2' in c]
print(f"H2 columns in export: {h2_cols}")

# %%
df.to_csv("predictions.csv")

# %%
def display_one_note(row: pd.Series) -> None:
    """Display a single note with H1 and H2 predictions and GPT justification."""
    sid = row.get("sid_key", "unknown")
    program = row.get("Program_Name", "N/A")
    po_number = row.get("PO_Number", "N/A")
    note = row.get("Scorecard_Note", "").strip()
    justification = row.get("justification", "").strip()

    # H1 prediction (original column names)
    color_h1 = row.get("predicted_color", "Unknown").title()
    p_green_h1 = f"{100 * row.get('prob_green', 0):.1f}%"
    p_yellow_h1 = f"{100 * row.get('prob_yellow', 0):.1f}%"
    p_red_h1 = f"{100 * row.get('prob_red', 0):.1f}%"
    
    # H2 prediction (with _h2 suffix)
    color_h2 = row.get("predicted_color_h2", None)
    if pd.notna(color_h2):
        color_h2 = str(color_h2).title()
        p_green_h2 = f"{100 * row.get('prob_green_h2', 0):.1f}%"
        p_yellow_h2 = f"{100 * row.get('prob_yellow_h2', 0):.1f}%"
        p_red_h2 = f"{100 * row.get('prob_red_h2', 0):.1f}%"
        h2_section = f"""### H2: Card After Next  
**Predicted Rating**: **{color_h2}**

- **Green**: {p_green_h2}  
- **Yellow**: {p_yellow_h2}  
- **Red**: {p_red_h2}"""
    else:
        h2_section = "### H2: Card After Next  \n*(Insufficient note history)*"

    # Safe handling for possibly missing or NaN target_label
    target_raw = row.get("target_label", "")
    target = str(target_raw).strip() if pd.notnull(target_raw) else "N/A"

    md = f"""
<hr style="border-top: 3px double red;">

**SID**: `{sid}`   **Program**: `{program}`   **PO Number**: `{po_number}`

---

### H1: Next Card  
**Predicted Rating**: **{color_h1}**

- **Green**: {p_green_h1}  
- **Yellow**: {p_yellow_h1}  
- **Red**: {p_red_h1}

---

{h2_section}

---

**Ground Truth**: **{target}**

---

**Raw Note**  
> {note}

---

**GPT Justification (H1)**  
{justification if justification else "*(No justification generated)*"}

---
"""
    display(Markdown(md))

# %%
from IPython.display import Markdown

sampled_df = sample_random_rag_notes()
for _, row in sampled_df.iterrows():
    display_one_note(row)
